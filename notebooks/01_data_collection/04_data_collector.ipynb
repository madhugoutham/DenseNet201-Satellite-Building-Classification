# %%
# %pip install geopandas requests shapely pandas tqdm
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (2.0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.6)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (24.1)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Run this cell to install required packages
# %pip install segment-geospatial geopandas folium ipywidgets google-auth-oauthlib google-auth-httplib2 google-api-python-client matplotlib descartes rasterio overpy segment-geospatial
# Out:
# Collecting segment-geospatial
#   Downloading segment_geospatial-0.12.2-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.18.0)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (7.7.1)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (2.137.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Collecting descartes
#   Downloading descartes-1.1.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting rasterio
#   Downloading rasterio-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting overpy
#   Downloading overpy-0.7-py3-none-any.whl.metadata (3.5 kB)
# Collecting fiona (from segment-geospatial)
#   Downloading fiona-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (5.2.0)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (0.24.7)
# Collecting ipympl (from segment-geospatial)
#   Downloading ipympl-0.9.4-py3-none-any.whl.metadata (8.7 kB)
# Collecting leafmap (from segment-geospatial)
#   Downloading leafmap-0.38.16-py2.py3-none-any.whl.metadata (16 kB)
# Collecting localtileserver (from segment-geospatial)
#   Downloading localtileserver-0.10.5-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (4.10.0.84)
# Collecting patool (from segment-geospatial)
#   Downloading patool-3.0.3-py2.py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (2.0.8)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (3.7.0)
# Collecting rioxarray (from segment-geospatial)
#   Downloading rioxarray-0.18.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting sam2 (from segment-geospatial)
#   Downloading sam2-0.4.1.tar.gz (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 kB 5.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (0.24.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (1.5.2)
# Collecting segment-anything-hq (from segment-geospatial)
#   Downloading segment_anything_hq-0.3-py3-none-any.whl.metadata (17 kB)
# Collecting segment-anything-py (from segment-geospatial)
#   Downloading segment_anything_py-1.0.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (1.0.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (4.66.6)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (2024.10.0)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (2024.9.0)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (24.1)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.2.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.6)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib) (2.27.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: httplib2>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-httplib2) (0.22.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (2.19.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (24.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.8.30)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Collecting cligj>=0.5 (from rasterio)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.65.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.25.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (4.9)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (75.1.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.5.5)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown->segment-geospatial) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown->segment-geospatial) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->segment-geospatial) (2024.10.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->segment-geospatial) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->segment-geospatial) (4.12.2)
# Collecting anywidget (from leafmap->segment-geospatial)
#   Downloading anywidget-0.9.13-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (0.12.43)
# Requirement already satisfied: colour in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (0.1.5)
# Collecting geojson (from leafmap->segment-geospatial)
#   Downloading geojson-3.1.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (2.0.2)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (0.19.2)
# Collecting ipyvuetify (from leafmap->segment-geospatial)
#   Downloading ipyvuetify-1.10.0-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (5.24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (5.9.5)
# Requirement already satisfied: pyshp in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (2.3.1)
# Collecting pystac-client (from leafmap->segment-geospatial)
#   Downloading pystac_client-0.8.5-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-box in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (7.2.0)
# Requirement already satisfied: scooby in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (0.10.0)
# Collecting whiteboxgui (from leafmap->segment-geospatial)
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: duckdb in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (1.1.2)
# Requirement already satisfied: flask<4,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from localtileserver->segment-geospatial) (2.2.5)
# Collecting Flask-Caching (from localtileserver->segment-geospatial)
#   Downloading Flask_Caching-2.3.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting flask-cors (from localtileserver->segment-geospatial)
#   Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting flask-restx>=1.3.0 (from localtileserver->segment-geospatial)
#   Downloading flask_restx-1.3.0-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting rio-tiler (from localtileserver->segment-geospatial)
#   Downloading rio_tiler-7.2.0-py3-none-any.whl.metadata (12 kB)
# Collecting rio-cogeo (from localtileserver->segment-geospatial)
#   Downloading rio_cogeo-5.3.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting server-thread (from localtileserver->segment-geospatial)
#   Downloading server_thread-0.2.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.10/dist-packages (from localtileserver->segment-geospatial) (3.0.6)
# Requirement already satisfied: torch>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from sam2->segment-geospatial) (2.5.0+cu121)
# Requirement already satisfied: torchvision>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from sam2->segment-geospatial) (0.20.0+cu121)
# Collecting hydra-core>=1.3.2 (from sam2->segment-geospatial)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting iopath>=0.1.10 (from sam2->segment-geospatial)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image->segment-geospatial) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->segment-geospatial) (3.4.2)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->segment-geospatial) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->segment-geospatial) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->segment-geospatial) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->segment-geospatial) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->segment-geospatial) (3.5.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm->segment-geospatial) (0.4.5)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask<4,>=2.0.0->localtileserver->segment-geospatial) (2.2.0)
# Collecting aniso8601>=0.82 (from flask-restx>=1.3.0->localtileserver->segment-geospatial)
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from flask-restx>=1.3.0->localtileserver->segment-geospatial) (4.23.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from flask-restx>=1.3.0->localtileserver->segment-geospatial) (6.4.5)
# Collecting omegaconf<2.4,>=2.2 (from hydra-core>=1.3.2->sam2->segment-geospatial)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.3.2->sam2->segment-geospatial)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 9.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting portalocker (from iopath>=0.1.10->sam2->segment-geospatial)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.4)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (7.16.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.21.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.13)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-auth-oauthlib) (0.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.1->sam2->segment-geospatial) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.3.1->sam2->segment-geospatial) (1.3.0)
# Collecting psygnal>=0.8.1 (from anywidget->leafmap->segment-geospatial)
#   Downloading psygnal-0.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown->segment-geospatial) (2.6)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.10/dist-packages (from bqplot->leafmap->segment-geospatial) (0.2.1)
# Collecting cachelib<0.10.0,>=0.9.0 (from Flask-Caching->localtileserver->segment-geospatial)
#   Downloading cachelib-0.9.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from ipyleaflet->leafmap->segment-geospatial) (0.19.2)
# Collecting ipyvue<2,>=1.7 (from ipyvuetify->leafmap->segment-geospatial)
#   Downloading ipyvue-1.11.1-py2.py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->leafmap->segment-geospatial) (9.0.0)
# Collecting pystac>=1.10.0 (from pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial)
#   Downloading pystac-1.11.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->segment-geospatial) (1.7.1)
# Collecting morecantile<6.0,>=5.0 (from rio-cogeo->localtileserver->segment-geospatial)
#   Downloading morecantile-5.4.2-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: pydantic~=2.0 in /usr/local/lib/python3.10/dist-packages (from rio-cogeo->localtileserver->segment-geospatial) (2.9.2)
# Collecting color-operations (from rio-tiler->localtileserver->segment-geospatial)
#   Downloading color_operations-0.1.6-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.0 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from rio-tiler->localtileserver->segment-geospatial) (0.27.2)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from rio-tiler->localtileserver->segment-geospatial) (2.10.1)
# Collecting uvicorn (from server-thread->localtileserver->segment-geospatial)
#   Downloading uvicorn-0.32.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: ipytree in /usr/local/lib/python3.10/dist-packages (from whiteboxgui->leafmap->segment-geospatial) (0.2.2)
# Collecting whitebox (from whiteboxgui->leafmap->segment-geospatial)
#   Downloading whitebox-2.3.5-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.3.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.20.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->segment-geospatial) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->segment-geospatial) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->segment-geospatial) (0.20.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic~=2.0->rio-cogeo->localtileserver->segment-geospatial) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic~=2.0->rio-cogeo->localtileserver->segment-geospatial) (2.23.4)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->rio-tiler->localtileserver->segment-geospatial) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->rio-tiler->localtileserver->segment-geospatial) (1.0.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->rio-tiler->localtileserver->segment-geospatial) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->rio-tiler->localtileserver->segment-geospatial) (0.14.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.24.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->rio-tiler->localtileserver->segment-geospatial) (1.2.2)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.22)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Downloading segment_geospatial-0.12.2-py2.py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 4.8 MB/s eta 0:00:00
# Downloading descartes-1.1.0-py3-none-any.whl (5.8 kB)
# Downloading rasterio-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 97.9 MB/s eta 0:00:00
# Downloading overpy-0.7-py3-none-any.whl (14 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Downloading fiona-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 99.5 MB/s eta 0:00:00
# Downloading ipympl-0.9.4-py3-none-any.whl (516 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.3/516.3 kB 27.9 MB/s eta 0:00:00
# Downloading leafmap-0.38.16-py2.py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.6/491.6 kB 27.7 MB/s eta 0:00:00
# Downloading localtileserver-0.10.5-py3-none-any.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 102.8 MB/s eta 0:00:00
# Downloading patool-3.0.3-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 6.4 MB/s eta 0:00:00
# Downloading rioxarray-0.18.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 4.3 MB/s eta 0:00:00
# Downloading segment_anything_hq-0.3-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.3 MB/s eta 0:00:00
# Downloading segment_anything_py-1.0.1-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 2.9 MB/s eta 0:00:00
# Downloading flask_restx-1.3.0-py2.py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 76.9 MB/s eta 0:00:00
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 10.7 MB/s eta 0:00:00
# Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.8 MB/s eta 0:00:00
# Downloading anywidget-0.9.13-py3-none-any.whl (213 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.7/213.7 kB 16.6 MB/s eta 0:00:00
# Downloading Flask_Caching-2.3.0-py3-none-any.whl (28 kB)
# Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl (14 kB)
# Downloading geojson-3.1.0-py3-none-any.whl (15 kB)
# Downloading ipyvuetify-1.10.0-py2.py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 90.9 MB/s eta 0:00:00
# Downloading pystac_client-0.8.5-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.8 MB/s eta 0:00:00
# Downloading rio_cogeo-5.3.6-py3-none-any.whl (20 kB)
# Downloading rio_tiler-7.2.0-py3-none-any.whl (265 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.6/265.6 kB 20.1 MB/s eta 0:00:00
# Downloading server_thread-0.2.0-py3-none-any.whl (8.5 kB)
# Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 7.0 MB/s eta 0:00:00
# Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 3.2 MB/s eta 0:00:00
# Downloading cachelib-0.9.0-py3-none-any.whl (15 kB)
# Downloading ipyvue-1.11.1-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 85.9 MB/s eta 0:00:00
# Downloading morecantile-5.4.2-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 2.8 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.5 MB/s eta 0:00:00
# Downloading psygnal-0.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (727 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.4/727.4 kB 37.5 MB/s eta 0:00:00
# Downloading pystac-1.11.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 12.3 MB/s eta 0:00:00
# Downloading color_operations-0.1.6-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (186 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.4/186.4 kB 11.6 MB/s eta 0:00:00
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading uvicorn-0.32.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 3.7 MB/s eta 0:00:00
# Downloading whitebox-2.3.5-py2.py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 kB 4.8 MB/s eta 0:00:00
# Building wheels for collected packages: sam2, antlr4-python3-runtime, iopath
#   Building wheel for sam2 (pyproject.toml) ... done
#   Created wheel for sam2: filename=sam2-0.4.1-cp310-cp310-linux_x86_64.whl size=85853 sha256=3a469c5214452e5a83622b1202fd4067d2fb3252ce6d6e89a2128e8dc28e0311
#   Stored in directory: /root/.cache/pip/wheels/f7/24/19/6ae406a45571a7fed8ef81297fc11698486638ac21200cdafa
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=44c412291b5a7946d855674add04e11a130597abed0b5798669fa03d2980ac20
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31528 sha256=ad308201213582664d8e54225c22f082ad08f2faec4bc8800b85ee24236dd0fa
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built sam2 antlr4-python3-runtime iopath
# Installing collected packages: antlr4-python3-runtime, aniso8601, whitebox, uvicorn, psygnal, portalocker, patool, overpy, omegaconf, jedi, geojson, color-operations, cligj, click-plugins, cachelib, affine, server-thread, rasterio, pystac, iopath, hydra-core, fiona, morecantile, flask-cors, Flask-Caching, descartes, segment-anything-py, segment-anything-hq, sam2, rioxarray, rio-tiler, rio-cogeo, flask-restx, pystac-client, localtileserver, ipyvue, ipympl, anywidget, whiteboxgui, ipyvuetify, leafmap, segment-geospatial
# Successfully installed Flask-Caching-2.3.0 affine-2.4.0 aniso8601-9.0.1 antlr4-python3-runtime-4.9.3 anywidget-0.9.13 cachelib-0.9.0 click-plugins-1.1.1 cligj-0.7.2 color-operations-0.1.6 descartes-1.1.0 fiona-1.10.1 flask-cors-5.0.0 flask-restx-1.3.0 geojson-3.1.0 hydra-core-1.3.2 iopath-0.1.10 ipympl-0.9.4 ipyvue-1.11.1 ipyvuetify-1.10.0 jedi-0.19.1 leafmap-0.38.16 localtileserver-0.10.5 morecantile-5.4.2 omegaconf-2.3.0 overpy-0.7 patool-3.0.3 portalocker-2.10.1 psygnal-0.11.1 pystac-1.11.0 pystac-client-0.8.5 rasterio-1.4.2 rio-cogeo-5.3.6 rio-tiler-7.2.0 rioxarray-0.18.1 sam2-0.4.1 segment-anything-hq-0.3 segment-anything-py-1.0.1 segment-geospatial-0.12.2 server-thread-0.2.0 uvicorn-0.32.0 whitebox-2.3.5 whiteboxgui-2.3.0

# %%
import geopandas as gpd
import requests
import json
from shapely.geometry import Polygon, MultiPolygon
import pandas as pd
import time
import random
from tqdm import tqdm

# Define the mapping of building types to classes
building_type_mapping = {
    # Residential
    'apartments': 'Multi',
    'residential': 'Multi',
    'house': 'Single',
    'detached': 'Single',
    'terrace': 'Multi',
    'semidetached_house': 'Single',
    'bungalow': 'Single',
    'farm': 'Single',
    'cabin': 'Single',
    # Commercial
    'commercial': 'Commercial',
    'retail': 'Commercial',
    'office': 'Commercial',
    'supermarket': 'Commercial',
    'hotel': 'Commercial',
    'mall': 'Commercial',
    'kiosk': 'Commercial',
    'shop': 'Commercial',
    'store': 'Commercial',
    'bank': 'Commercial',
    'restaurant': 'Commercial',
    'bar': 'Commercial',
    'cafe': 'Commercial',
    'barber_shop': 'Commercial',
    # Industrial
    'industrial': 'Industrial',
    'warehouse': 'Industrial',
    'manufacture': 'Industrial',
    'factory': 'Industrial',
    'depot': 'Industrial',
    'power_station': 'Industrial',
    'refinery': 'Industrial',
    'mining': 'Industrial',
    'mill': 'Industrial',
    'shipyard': 'Industrial',
    # Educational
    'school': 'Schools',
    'university': 'Schools',
    'college': 'Schools',
    'kindergarten': 'Schools',
    'academy': 'Schools',
    'institute': 'Schools',
    'library': 'Schools',
    'research_institute': 'Schools',
    # Healthcare
    'hospital': 'Hospital',
    'clinic': 'Hospital',
    'healthcare': 'Hospital',
    'medical_center': 'Hospital',
    'nursing_home': 'Hospital',
    # High-rise Buildings
    'highrise': 'High',
    'tower': 'High',
    'skyscraper': 'High',
    'high-rise': 'High',
    'office_tower': 'High',
    'residential_tower': 'High',
    # Add more mappings as needed
}

def classify_building(tags):
    """
    Classifies a building into one of the target classes based on tags and other attributes.
    """
    building_type = tags.get('building', '').lower()
    building_levels = tags.get('building:levels')
    building_height = tags.get('height')
    building_use = tags.get('building:use', '').lower()

    # Direct mapping based on building_type
    if building_type in building_type_mapping:
        return building_type_mapping[building_type]

    # Handling 'public' building_type
    if building_type == 'public':
        # Use building_use or building_levels to refine classification
        if building_use:
            if 'school' in building_use or 'education' in building_use:
                return 'Schools'
            elif 'hospital' in building_use or 'healthcare' in building_use:
                return 'Hospital'
            elif 'government' in building_use or 'office' in building_use:
                return 'Commercial'  # Assuming government offices are classified as Commercial
            else:
                return 'Commercial'  # Default to Commercial
        else:
            return 'Commercial'  # Default to Commercial

    # Handling based on building_levels or building_height for 'High' class
    if building_levels:
        try:
            levels = int(building_levels)
            if levels >= 5:
                return 'High'
            elif levels >= 2:
                return 'Multi'
            else:
                return 'Single'
        except ValueError:
            pass  # If building_levels is not an integer, ignore
    elif building_height:
        try:
            # Remove any units (e.g., 'm' for meters)
            height_str = str(building_height).replace('m', '').strip()
            height = float(height_str)
            if height >= 15:  # Approximate height for a high-rise
                return 'High'
            elif height >= 7:
                return 'Multi'
            else:
                return 'Single'
        except ValueError:
            pass  # If building_height is not a float, ignore

    # Default classification
    return 'Single'  # Default to 'Single' if no other classification applies

def get_zip_polygon(zip_code, zcta_gdf):
    """
    Retrieves the polygon geometry for a given ZIP code from the GeoDataFrame.
    """
    zip_code = str(zip_code).zfill(5)
    zip_area = zcta_gdf[zcta_gdf['ZCTA5CE20'] == zip_code]

    if zip_area.empty:
        return None  # ZIP code not found

    return zip_area.geometry.values[0]

def get_poly_coords(polygon):
    """
    Extracts coordinates from a Polygon or MultiPolygon object.
    """
    coords = []
    if isinstance(polygon, Polygon):
        exterior = polygon.exterior.coords
        coords.extend([(y, x) for x, y in exterior])
    elif isinstance(polygon, MultiPolygon):
        for poly in polygon.geoms:
            exterior = poly.exterior.coords
            coords.extend([(y, x) for x, y in exterior])
    else:
        raise ValueError("Geometry must be a Polygon or MultiPolygon.")
    return coords

def fetch_buildings_for_zip(zip_code, zcta_gdf, overpass_url, query_template, max_retries=3, delay=1):
    """
    Fetches building data for a specific ZIP code using Overpass API.
    """
    zip_polygon = get_zip_polygon(zip_code, zcta_gdf)
    if not zip_polygon:
        print(f"ZIP code {zip_code} not found. Skipping.")
        return []

    coords = get_poly_coords(zip_polygon)
    poly_string = ' '.join(['{} {}'.format(lat, lon) for lat, lon in coords])
    query = f'''
    [out:json][timeout:25];
    (
      way(poly:"{poly_string}") [building];
    );
    out geom;
    '''

    for attempt in range(max_retries):
        try:
            response = requests.post(overpass_url, data={'data': query})
            if response.status_code == 200:
                data = response.json()
                return data.get('elements', [])
            else:
                print(f"Overpass API request failed with status code {response.status_code}. Retrying...")
        except Exception as e:
            print(f"Exception during Overpass API request: {e}. Retrying...")
        time.sleep(delay * (attempt + 1))  # Exponential backoff
    print(f"Failed to fetch data for ZIP code {zip_code} after {max_retries} attempts.")
    return []

def process_building_element(element):
    """
    Processes a single building element from Overpass API response.
    """
    building_id = element.get('id')
    tags = element.get('tags', {})
    building_type = tags.get('building')  # Extract the building type
    building_levels = tags.get('building:levels')
    building_material = tags.get('building:material')
    building_height = tags.get('height')
    building_use = tags.get('building:use')

    # Classify the building
    building_class = classify_building(tags)

    if 'geometry' in element:
        coords = [(node['lon'], node['lat']) for node in element['geometry']]
        try:
            poly = Polygon(coords)
            minx, miny, maxx, maxy = poly.bounds  # Bounding box coordinates

            # Define the four corner points of the bounding box
            corner1 = {'lat': miny, 'lon': minx}  # Bottom-left
            corner2 = {'lat': miny, 'lon': maxx}  # Bottom-right
            corner3 = {'lat': maxy, 'lon': maxx}  # Top-right
            corner4 = {'lat': maxy, 'lon': minx}  # Top-left

            return {
                'building_id': building_id,
                'building_type': building_type,  # Store the building type
                'building_class': building_class,  # Store the building class
                'corner1_lat': corner1['lat'],
                'corner1_lon': corner1['lon'],
                'corner2_lat': corner2['lat'],
                'corner2_lon': corner2['lon'],
                'corner3_lat': corner3['lat'],
                'corner3_lon': corner3['lon'],
                'corner4_lat': corner4['lat'],
                'corner4_lon': corner4['lon'],
                'building_levels': building_levels,
                'building_material': building_material,
                'building_height': building_height,
                'building_use': building_use,
            }
        except Exception as e:
            print(f"Error creating polygon for element ID {building_id}: {e}")
    else:
        print(f"No geometry found for element ID {building_id}")

    return None  # Return None if processing fails

def collect_building_data():
    # Define constants
    OVERPASS_URL = 'http://overpass-api.de/api/interpreter'
    SHAPEFILE_PATH = "/content/drive/MyDrive/Madhu RA Work Folder/Zip/tl_2022_us_zcta520.shp"
    OUTPUT_CSV_PATH = '/content/drive/MyDrive/Madhu RA Work Folder/newdata/Buildings_USA.csv'
    DESIRED_COUNT_PER_CLASS = 2000
    TARGET_CLASSES = ['Single', 'Multi', 'Commercial', 'Industrial', 'Schools', 'Hospital', 'High']
    MAX_RETRIES = 3
    REQUEST_DELAY = 1

    # Load the ZIP code shapefile
    print("Loading ZIP code shapefile...")
    zcta_gdf = gpd.read_file(SHAPEFILE_PATH)
    print(f"Total ZIP codes loaded: {len(zcta_gdf)}")

    # Extract all ZIP codes
    all_zip_codes = zcta_gdf['ZCTA5CE20'].tolist()
    print("Total ZIP codes to process:", len(all_zip_codes))

    # Shuffle ZIP codes to ensure random distribution across states
    random.shuffle(all_zip_codes)

    # Initialize data storage
    building_data = []
    class_counts = {cls: 0 for cls in TARGET_CLASSES}

    # Iterate over ZIP codes
    for zip_code in tqdm(all_zip_codes, desc="Processing ZIP codes"):
        if all(count >= DESIRED_COUNT_PER_CLASS for count in class_counts.values()):
            print("Desired number of buildings per class reached. Stopping data collection.")
            break

        elements = fetch_buildings_for_zip(
            zip_code=zip_code,
            zcta_gdf=zcta_gdf,
            overpass_url=OVERPASS_URL,
            query_template=None,  # Not used in current implementation
            max_retries=MAX_RETRIES,
            delay=REQUEST_DELAY
        )
        if not elements:
            continue  # Skip if no data fetched

        for element in elements:
            building = process_building_element(element)
            if building:
                cls = building['building_class']
                if cls in TARGET_CLASSES and class_counts[cls] < DESIRED_COUNT_PER_CLASS:
                    building_data.append(building)
                    class_counts[cls] += 1

                    # Check if the class has reached the desired count
                    if class_counts[cls] >= DESIRED_COUNT_PER_CLASS:
                        print(f"Reached desired count for class: {cls}")

                # Optional: Stop early if all classes are filled
                if all(count >= DESIRED_COUNT_PER_CLASS for count in class_counts.values()):
                    break

        # Respect API rate limits
        time.sleep(REQUEST_DELAY + random.uniform(0, 1))  # Randomize delay to avoid patterns

    print("Data collection completed.")
    print("Building counts per class:")
    for cls, count in class_counts.items():
        print(f"{cls}: {count}")

    # Convert to DataFrame
    df = pd.DataFrame(building_data)

    # Save to CSV
    df.to_csv(OUTPUT_CSV_PATH, index=False)
    print(f"Building data saved to {OUTPUT_CSV_PATH}")
if __name__ == "__main__":
    collect_building_data()
# Out:
# Loading ZIP code shapefile...
# Total ZIP codes loaded: 33791
# Total ZIP codes to process: 33791
# Processing ZIP codes:   0%|          | 1/33791 [00:01<16:59:53,  1.81s/it]
# Reached desired count for class: Single
# Processing ZIP codes:   0%|          | 14/33791 [00:44<36:44:00,  3.92s/it]
# Reached desired count for class: Multi
# Processing ZIP codes:   0%|          | 165/33791 [12:58<82:31:29,  8.84s/it]
# Reached desired count for class: Commercial
# Processing ZIP codes:   1%|          | 343/33791 [27:57<92:53:07, 10.00s/it]
# Reached desired count for class: Schools
# Processing ZIP codes:   1%|          | 385/33791 [31:48<84:40:21,  9.12s/it]
# Reached desired count for class: Industrial
# Processing ZIP codes:   3%|▎         | 1045/33791 [1:28:07<33:58:29,  3.74s/it]
# Reached desired count for class: High
# Processing ZIP codes:   6%|▌         | 2095/33791 [2:54:29<20:57:40,  2.38s/it]
# Overpass API request failed with status code 500. Retrying...
# Overpass API request failed with status code 500. Retrying...
# Overpass API request failed with status code 500. Retrying...
# Processing ZIP codes:   6%|▌         | 2096/33791 [3:00:08<908:09:09, 103.15s/it]
# Failed to fetch data for ZIP code 22202 after 3 attempts.
# Processing ZIP codes:   9%|▉         | 3031/33791 [4:23:00<86:50:15, 10.16s/it]
# Error creating polygon for element ID 195438334: A linearring requires at least 4 coordinates.
# Processing ZIP codes:  20%|█▉        | 6625/33791 [9:21:10<20:01:14,  2.65s/it]
# Error creating polygon for element ID 833587741: A linearring requires at least 4 coordinates.
# Processing ZIP codes:  20%|█▉        | 6671/33791 [9:25:13<47:01:25,  6.24s/it]
# Reached desired count for class: Hospital
# Processing ZIP codes:  20%|█▉        | 6672/33791 [9:25:36<38:18:58,  5.09s/it]
# Desired number of buildings per class reached. Stopping data collection.
# Data collection completed.
# Building counts per class:
# Single: 2000
# Multi: 2000
# Commercial: 2000
# Industrial: 2000
# Schools: 2000
# Hospital: 2000
# High: 2000
# Building data saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Buildings_USA.csv

# %%
import geopandas as gpd
import requests
import json
from shapely.geometry import Polygon, MultiPolygon
import pandas as pd
import time
import random
from tqdm import tqdm

# Define the mapping of building types to classes
building_type_mapping = {
    # Residential
    'apartments': 'Multi',
    'residential': 'Multi',
    'house': 'Single',
    'detached': 'Single',
    'terrace': 'Multi',
    'semidetached_house': 'Single',
    'bungalow': 'Single',
    'farm': 'Single',
    'cabin': 'Single',
    # Commercial
    'commercial': 'Commercial',
    'retail': 'Commercial',
    'office': 'Commercial',
    'supermarket': 'Commercial',
    'hotel': 'Commercial',
    'mall': 'Commercial',
    'kiosk': 'Commercial',
    'shop': 'Commercial',
    'store': 'Commercial',
    'bank': 'Commercial',
    'restaurant': 'Commercial',
    'bar': 'Commercial',
    'cafe': 'Commercial',
    'barber_shop': 'Commercial',
    # Industrial
    'industrial': 'Industrial',
    'warehouse': 'Industrial',
    'manufacture': 'Industrial',
    'factory': 'Industrial',
    'depot': 'Industrial',
    'power_station': 'Industrial',
    'refinery': 'Industrial',
    'mining': 'Industrial',
    'mill': 'Industrial',
    'shipyard': 'Industrial',
    # Educational
    'school': 'Schools',
    'university': 'Schools',
    'college': 'Schools',
    'kindergarten': 'Schools',
    'academy': 'Schools',
    'institute': 'Schools',
    'library': 'Schools',
    'research_institute': 'Schools',
    # Healthcare
    'hospital': 'Hospital',
    'clinic': 'Hospital',
    'healthcare': 'Hospital',
    'medical_center': 'Hospital',
    'nursing_home': 'Hospital',
    # High-rise Buildings
    'highrise': 'High',
    'tower': 'High',
    'skyscraper': 'High',
    'high-rise': 'High',
    'office_tower': 'High',
    'residential_tower': 'High',
    # Add more mappings as needed
}

def classify_building(tags):
    building_type = tags.get('building', '').lower()
    return building_type_mapping.get(building_type, 'Single')

def get_location_info(zip_code, zcta_gdf):
    zip_code = str(zip_code).zfill(5)
    zip_area = zcta_gdf[zcta_gdf['ZCTA5CE20'] == zip_code]

    if zip_area.empty:
        return None, None, None

    state = zip_area.iloc[0]['STATE'] if 'STATE' in zip_area.columns else None
    county = zip_area.iloc[0]['COUNTY'] if 'COUNTY' in zip_area.columns else None
    return zip_code, state, county

def process_building_element(element, zip_code, zcta_gdf):
    building_id = element.get('id')
    tags = element.get('tags', {})
    building_class = classify_building(tags)

    zip_code, state, county = get_location_info(zip_code, zcta_gdf)

    if 'geometry' in element:
        coords = [(node['lon'], node['lat']) for node in element['geometry']]
        try:
            poly = Polygon(coords)
            minx, miny, maxx, maxy = poly.bounds

            corner1 = {'lat': miny, 'lon': minx}
            corner2 = {'lat': miny, 'lon': maxx}
            corner3 = {'lat': maxy, 'lon': maxx}
            corner4 = {'lat': maxy, 'lon': minx}

            return {
                'building_id': building_id,
                'building_class': building_class,
                'corner1_lat': corner1['lat'],
                'corner1_lon': corner1['lon'],
                'corner2_lat': corner2['lat'],
                'corner2_lon': corner2['lon'],
                'corner3_lat': corner3['lat'],
                'corner3_lon': corner3['lon'],
                'corner4_lat': corner4['lat'],
                'corner4_lon': corner4['lon'],
                'zip_code': zip_code,
                'state': state,
                'county': county,
            }
        except Exception as e:
            print(f"Error creating polygon for element ID {building_id}: {e}")
    else:
        print(f"No geometry found for element ID {building_id}")

    return None

def collect_building_data():
    OVERPASS_URL = 'http://overpass-api.de/api/interpreter'
    SHAPEFILE_PATH = "/content/drive/MyDrive/Madhu RA Work Folder/Zip/tl_2022_us_zcta520.shp"
    OUTPUT_CSV_PATH = '/content/drive/MyDrive/Madhu RA Work Folder/newdata/Buildings_USA_st.csv'
    DESIRED_COUNT_PER_CLASS = 2000
    TARGET_CLASSES = ['Single', 'Multi', 'Commercial', 'Industrial', 'Schools', 'Hospital', 'High']
    MAX_RETRIES = 3
    REQUEST_DELAY = 1

    print("Loading ZIP code shapefile...")
    zcta_gdf = gpd.read_file(SHAPEFILE_PATH)
    print(f"Total ZIP codes loaded: {len(zcta_gdf)}")

    all_zip_codes = zcta_gdf['ZCTA5CE20'].tolist()
    print("Total ZIP codes to process:", len(all_zip_codes))

    random.shuffle(all_zip_codes)
    building_data = []
    class_counts = {cls: 0 for cls in TARGET_CLASSES}

    for zip_code in tqdm(all_zip_codes, desc="Processing ZIP codes"):
        if all(count >= DESIRED_COUNT_PER_CLASS for count in class_counts.values()):
            print("Desired number of buildings per class reached. Stopping data collection.")
            break

        elements = fetch_buildings_for_zip(
            zip_code=zip_code,
            zcta_gdf=zcta_gdf,
            overpass_url=OVERPASS_URL,
            query_template=None,
            max_retries=MAX_RETRIES,
            delay=REQUEST_DELAY
        )
        if not elements:
            continue

        for element in elements:
            building = process_building_element(element, zip_code, zcta_gdf)
            if building:
                cls = building['building_class']
                if cls in TARGET_CLASSES and class_counts[cls] < DESIRED_COUNT_PER_CLASS:
                    building_data.append(building)
                    class_counts[cls] += 1

                if all(count >= DESIRED_COUNT_PER_CLASS for count in class_counts.values()):
                    break

        time.sleep(REQUEST_DELAY + random.uniform(0, 1))

    print("Data collection completed.")
    df = pd.DataFrame(building_data)
    df.to_csv(OUTPUT_CSV_PATH, index=False)
    print(f"Building data saved to {OUTPUT_CSV_PATH}")

if __name__ == "__main__":
    collect_building_data()

# %%
import os
import pandas as pd
from samgeo import tms_to_geotiff
from PIL import Image
import time
from math import cos, radians

def download_and_resize_image(image_path, bbox, zoom, source, output_size):
    try:
        #Download the image using the geographic bounding box
        tms_to_geotiff(output=image_path, bbox=bbox, zoom=zoom, source=source, overwrite=True)

        #Open the downloaded image
        with Image.open(image_path) as img:
            original_size = img.size

            #Resize the image to the desired dimensions while maintaining aspect ratio
            img_resized = img.resize(output_size, Image.LANCZOS)
            img_resized.save(image_path)

            return original_size, img_resized.size
    except Exception as e:
        print(f"Failed to download or resize image for bbox {bbox}. Error: {e}")
        return None, None

# %%
import os
import pandas as pd
import time
from math import radians, cos

def main():
    import os
    import pandas as pd
    import time
    from math import radians, cos

    # Required functions (assuming they are defined elsewhere in your code)
    # from your_module import download_and_resize_image

    zoom = 22  # Adjust zoom level as needed
    source = "Satellite"

    # Bounding box expansion factor (e.g., 0.1 for 10% expansion)
    bbox_expansion_factor = 0.3  # Adjust this value to control the space around the building

    # Desired image height in pixels (you can adjust this)
    desired_image_height = 500  # pixels

    df = pd.read_csv('/content/drive/MyDrive/Madhu RA Work Folder/newdata/Buildings_USA.csv')

    output_base_dir = '/content/drive/MyDrive/Madhu RA Work Folder/newdata'

    # Dictionary to keep track of counts per class
    class_counts = {}
    max_images_per_class = 2000

    # Loop over each building in the DataFrame
    for index, row in df.iterrows():
        building_id = row['building_id']
        building_class = row['building_class']
        if pd.isnull(building_class):
            continue  # Skip buildings with no class

        # Initialize count for this class if not already done
        if building_class not in class_counts:
            class_counts[building_class] = 0

        # Check if we have already downloaded 50 images for this class
        if class_counts[building_class] >= max_images_per_class:
            continue  # Skip to next building

        # Get the corner coordinates from the CSV
        corner1_lat = row['corner1_lat']
        corner1_lon = row['corner1_lon']
        corner2_lat = row['corner2_lat']
        corner2_lon = row['corner2_lon']
        corner3_lat = row['corner3_lat']
        corner3_lon = row['corner3_lon']
        corner4_lat = row['corner4_lat']
        corner4_lon = row['corner4_lon']

        # Compute min and max latitudes and longitudes from the corners
        latitudes = [corner1_lat, corner2_lat, corner3_lat, corner4_lat]
        longitudes = [corner1_lon, corner2_lon, corner3_lon, corner4_lon]
        min_lat = min(latitudes)
        max_lat = max(latitudes)
        min_lon = min(longitudes)
        max_lon = max(longitudes)

        # Calculate the width and height of the bounding box in degrees
        width_deg = max_lon - min_lon
        height_deg = max_lat - min_lat

        # Expand the bounding box by the expansion factor
        min_lon_expanded = min_lon - (width_deg * bbox_expansion_factor / 2)
        max_lon_expanded = max_lon + (width_deg * bbox_expansion_factor / 2)
        min_lat_expanded = min_lat - (height_deg * bbox_expansion_factor / 2)
        max_lat_expanded = max_lat + (height_deg * bbox_expansion_factor / 2)

        # Calculate the center latitude for distance calculations
        center_lat = (min_lat_expanded + max_lat_expanded) / 2.0

        # Convert degrees to radians for trigonometric functions
        lat_rad = radians(center_lat)

        # Approximate meters per degree latitude and longitude
        meters_per_deg_lat = 111320  # meters per degree latitude is approximately constant
        meters_per_deg_lon = 111320 * cos(lat_rad)  # varies with latitude

        # Calculate physical width and height in meters
        width_meters = (max_lon_expanded - min_lon_expanded) * meters_per_deg_lon
        height_meters = (max_lat_expanded - min_lat_expanded) * meters_per_deg_lat

        # Calculate the aspect ratio
        aspect_ratio = width_meters / height_meters

        # Calculate the desired image width based on the aspect ratio
        desired_image_width = int(desired_image_height * aspect_ratio)

        # Ensure the width is at least 1 pixel
        desired_image_width = max(desired_image_width, 1)

        # Define the output image size
        output_size = (desired_image_width, desired_image_height)

        # Create expanded bbox
        bbox = [min_lon_expanded, min_lat_expanded, max_lon_expanded, max_lat_expanded]
        print(f"Processing building ID {building_id} with expanded bbox {bbox}")

        # Create the output directory for this class if it doesn't exist
        class_output_dir = os.path.join(output_base_dir, building_class)
        os.makedirs(class_output_dir, exist_ok=True)

        # Define the image file path using the building ID
        image_filename = f"building_{building_id}.tif"
        image_path = os.path.join(class_output_dir, image_filename)

        # Download and resize the image
        original_size, resized_size = download_and_resize_image(
            image_path, bbox, zoom, source, output_size)

        if original_size and resized_size:
            print(f"Image saved for building ID {building_id}")
            # Increment the count for this class
            class_counts[building_class] += 1
        else:
            print(f"Failed to download image for building ID {building_id}")

        # Check if we have reached the maximum images for this class
        if class_counts[building_class] >= max_images_per_class:
            print(f"Reached maximum images for class '{building_class}'")
            continue  # Continue to next building

        # Sleep to respect server rate limits
        time.sleep(1)

        # Optional: Break if all classes have reached the maximum
        if all(count >= max_images_per_class for count in class_counts.values()):
            print("Reached maximum images for all classes")
            break

if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# Downloaded image 061/154
# Downloaded image 062/154
# Downloaded image 063/154
# Downloaded image 064/154
# Downloaded image 065/154
# Downloaded image 066/154
# Downloaded image 067/154
# Downloaded image 068/154
# Downloaded image 069/154
# Downloaded image 070/154
# Downloaded image 071/154
# Downloaded image 072/154
# Downloaded image 073/154
# Downloaded image 074/154
# Downloaded image 075/154
# Downloaded image 076/154
# Downloaded image 077/154
# Downloaded image 078/154
# Downloaded image 079/154
# Downloaded image 080/154
# Downloaded image 081/154
# Downloaded image 082/154
# Downloaded image 083/154
# Downloaded image 084/154
# Downloaded image 085/154
# Downloaded image 086/154
# Downloaded image 087/154
# Downloaded image 088/154
# Downloaded image 089/154
# Downloaded image 090/154
# Downloaded image 091/154
# Downloaded image 092/154
# Downloaded image 093/154
# Downloaded image 094/154
# Downloaded image 095/154
# Downloaded image 096/154
# Downloaded image 097/154
# Downloaded image 098/154
# Downloaded image 099/154
# Downloaded image 100/154
# Downloaded image 101/154
# Downloaded image 102/154
# Downloaded image 103/154
# Downloaded image 104/154
# Downloaded image 105/154
# Downloaded image 106/154
# Downloaded image 107/154
# Downloaded image 108/154
# Downloaded image 109/154
# Downloaded image 110/154
# Downloaded image 111/154
# Downloaded image 112/154
# Downloaded image 113/154
# Downloaded image 114/154
# Downloaded image 115/154
# Downloaded image 116/154
# Downloaded image 117/154
# Downloaded image 118/154
# Downloaded image 119/154
# Downloaded image 120/154
# Downloaded image 121/154
# Downloaded image 122/154
# Downloaded image 123/154
# Downloaded image 124/154
# Downloaded image 125/154
# Downloaded image 126/154
# Downloaded image 127/154
# Downloaded image 128/154
# Downloaded image 129/154
# Downloaded image 130/154
# Downloaded image 131/154
# Downloaded image 132/154
# Downloaded image 133/154
# Downloaded image 134/154
# Downloaded image 135/154
# Downloaded image 136/154
# Downloaded image 137/154
# Downloaded image 138/154
# Downloaded image 139/154
# Downloaded image 140/154
# Downloaded image 141/154
# Downloaded image 142/154
# Downloaded image 143/154
# Downloaded image 144/154
# Downloaded image 145/154
# Downloaded image 146/154
# Downloaded image 147/154
# Downloaded image 148/154
# Downloaded image 149/154
# Downloaded image 150/154
# Downloaded image 151/154
# Downloaded image 152/154
# Downloaded image 153/154
# Downloaded image 154/154
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_
# Downloaded image 64/99
# Downloaded image 65/99
# Downloaded image 66/99
# Downloaded image 67/99
# Downloaded image 68/99
# Downloaded image 69/99
# Downloaded image 70/99
# Downloaded image 71/99
# Downloaded image 72/99
# Downloaded image 73/99
# Downloaded image 74/99
# Downloaded image 75/99
# Downloaded image 76/99
# Downloaded image 77/99
# Downloaded image 78/99
# Downloaded image 79/99
# Downloaded image 80/99
# Downloaded image 81/99
# Downloaded image 82/99
# Downloaded image 83/99
# Downloaded image 84/99
# Downloaded image 85/99
# Downloaded image 86/99
# Downloaded image 87/99
# Downloaded image 88/99
# Downloaded image 89/99
# Downloaded image 90/99
# Downloaded image 91/99
# Downloaded image 92/99
# Downloaded image 93/99
# Downloaded image 94/99
# Downloaded image 95/99
# Downloaded image 96/99
# Downloaded image 97/99
# Downloaded image 98/99
# Downloaded image 99/99
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_300522752.tif
# Image saved for building ID 300522752
# Processing building ID 300522753 with expanded bbox [-95.25813098, 41.01542009, -95.25797861999999, 41.01607191]
# Downloaded image 01/33
# Downloaded image 02/33
# Downloaded image 03/33
# Downloaded image 04/33
# Downloaded image 05/33
# Downloaded image 06/33
# Downloaded image 07/33
# Downloaded image 08/33
# Downloaded image 09/33
# Downloaded image 10/33
# Downloaded image 11/33
# Downloaded image 12/33
# Downloaded image 13/33
# Downloaded image 14/33
# Downloaded image 15/33
# Downloaded image 16/33
# Downloaded image 17/33
# Downloaded image 18/33
# Downloaded image 19/33
# Downloaded image 20/33
# Downloaded image 21/33
# Downloaded image 22/33
# Downloaded image 23/33
# Downloaded image 24/33
# Downloaded image 25/33
# Downloaded image 26/33
# Downloaded image 27/33
# Downloaded image 28/33
# Downloaded image 29/33
# Downloaded image 30/33
# Downloaded image 31/33
# Downloaded image 32/33
# Downloaded image 33/33
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_300522753.tif
# Image saved for building ID 300522753
# Processing building ID 300522754 with expanded bbox [-95.256308355, 41.014743335, -95.255708145, 41.015285565]
# Downloaded image 01/80
# Downloaded image 02/80
# Downloaded image 03/80
# Downloaded image 04/80
# Downloaded image 05/80
# Downloaded image 06/80
# Downloaded image 07/80
# Downloaded image 08/80
# Downloaded image 09/80
# Downloaded image 10/80
# Downloaded image 11/80
# Downloaded image 12/80
# Downloaded image 13/80
# Downloaded image 14/80
# Downloaded image 15/80
# Downloaded image 16/80
# Downloaded image 17/80
# Downloaded image 18/80
# Downloaded image 19/80
# Downloaded image 20/80
# Downloaded image 21/80
# Downloaded image 22/80
# Downloaded image 23/80
# Downloaded image 24/80
# Downloaded image 25/80
# Downloaded image 26/80
# Downloaded image 27/80
# Downloaded image 28/80
# Downloaded image 29/80
# Downloaded image 30/80
# Downloaded image 31/80
# Downloaded image 32/80
# Downloaded image 33/80
# Downloaded image 34/80
# Downloaded image 35/80
# Downloaded image 36/80
# Downloaded image 37/80
# Downloaded image 38/80
# Downloaded image 39/80
# Downloaded image 40/80
# Downloaded image 41/80
# Downloaded image 42/80
# Downloaded image 43/80
# Downloaded image 44/80
# Downloaded image 45/80
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_300522761.tif
# Image saved for building ID 300522761
# Processing building ID 540042893 with expanded bbox [-95.22175259, 41.01225007, -95.22140861000001, 41.01298613]
# Downloaded image 01/60
# Downloaded image 02/60
# Downloaded image 03/60
# Downloaded image 04/60
# Downloaded image 05/60
# Downloaded image 06/60
# Downloaded image 07/60
# Downloaded image 08/60
# Downloaded image 09/60
# Downloaded image 10/60
# Downloaded image 11/60
# Downloaded image 12/60
# Downloaded image 13/60
# Downloaded image 14/60
# Downloaded image 15/60
# Downloaded image 16/60
# Downloaded image 17/60
# Downloaded image 18/60
# Downloaded image 19/60
# Downloaded image 20/60
# Downloaded image 21/60
# Downloaded image 22/60
# Downloaded image 23/60
# Downloaded image 24/60
# Downloaded image 25/60
# Downloaded image 26/60
# Downloaded image 27/60
# Downloaded image 28/60
# Downloaded image 29/60
# Downloaded image 30/60
# Downloaded image 31/60
# Downloaded image 32/60
# Downloaded image 33/60
# Downloaded image 34/60
# Downloaded image 35/60
# Downloaded image 36/60
# Downloaded image 37/60
# Downloaded image 38/60
# Downloaded image 39/60
# Downloaded image 40/60
# Downloaded image 41/60
# Downloaded image 42/60
# Downloaded image 43/60
# Downloaded image 44/60
# Downloaded image 45/60
# Downloaded image 46/60
# Downloaded image 47/60
# Downloaded image 48/60
# Downloaded image 49/60
# Downloaded image 50/60
# Downloaded image 51/60
# Downloaded image 52/60
# Downloaded image 53/60
# Downloaded image 54/60
# Downloaded image 55/60
# Downloaded image 56/60
# Downloaded image 57/60
# Downloaded image 58/60
# Downloaded image 59/60
# Downloaded image 60/60
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Schools/building_540042893.tif
# Image saved for building ID 540042893
# Processing building ID 744319977 with expanded bbox [-95.22745126999999, 41.008448445, -95.22735273, 41.008874455]
# Downloaded image 01/16
# Downloaded image 02/16
# Downloaded image 03/16
# Downloaded image 04/16
# Downloaded image 05/16
# Downloaded image 06/16
# Downloaded image 07/16
# Downloaded image 08/16
# Downloaded image 09/16
# Downloaded image 10/16
# Downloaded image 11/16
# Downloaded image 12/16
# Downloaded image 13/16
# Downloaded image 14/16
# Downloaded image 15/16
# Downloaded image 16/16
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_744319977.tif
# Image saved for building ID 744319977
# Processing building ID 1101221002 with expanded bbox [-95.22843044000001, 41.009114585, -95.22825415999999, 41.009242115]
# Downloaded image 1/9
# Downloaded image 2/9
# Downloaded image 3/9
# Downloaded image 4/9
# Downloaded image 5/9
# Downloaded image 6/9
# Downloaded image 7/9
# Downloaded image 8/9
# Downloaded image 9/9
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1101221002.tif
# Image saved for building ID 1101221002
# Processing building ID 1101223529 with expanded bbox [-95.223204975, 41.026437285, -95.222328125, 41.026835215]
# Downloaded image 01/77
# Downloaded image 02/77
# Downloaded image 03/77
# Downloaded image 04/77
# Downloaded image 05/77
# Downloaded image 06/77
# Downloaded image 07/77
# Downloaded image 08/77
# Downloaded image 09/77
# Downloaded image 10/77
# Downloaded image 11/77
# Downloaded image 12/77
# Downloaded image 13/77
# Downloaded image 14/77
# Downloaded image 15/77
# Downloaded image 16/77
# Downloaded image 17/77
# Downloaded image 18/77
# Downloaded image 19/77
# Downloaded image 20/77
# Downloaded image 21/77
# Downloaded image 22/77
# Downloaded image 23/77
# Downloaded image 24/77
# Downloaded image 25/77
# Downloaded image 26/77
# Downloaded image 27/77
# Downloaded image 28/77
# Downloaded image 29/77
# Downloaded image 30/77
# Downloaded image 31/77
# Downloaded image 32/77
# Downloaded image 33/77
# Downloaded image 34/77
# Downloaded image 35/77

# Downloaded image 01/12
# Downloaded image 02/12
# Downloaded image 03/12
# Downloaded image 04/12
# Downloaded image 05/12
# Downloaded image 06/12
# Downloaded image 07/12
# Downloaded image 08/12
# Downloaded image 09/12
# Downloaded image 10/12
# Downloaded image 11/12
# Downloaded image 12/12
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506345.tif
# Image saved for building ID 1313506345
# Processing building ID 1313506346 with expanded bbox [-95.23260001999999, 41.014661175, -95.23243518000001, 41.014808725]
# Downloaded image 1/9
# Downloaded image 2/9
# Downloaded image 3/9
# Downloaded image 4/9
# Downloaded image 5/9
# Downloaded image 6/9
# Downloaded image 7/9
# Downloaded image 8/9
# Downloaded image 9/9
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506346.tif
# Image saved for building ID 1313506346
# Processing building ID 1313506347 with expanded bbox [-95.23243124999999, 41.01465052, -95.23227915000001, 41.01483148]
# Downloaded image 01/12
# Downloaded image 02/12
# Downloaded image 03/12
# Downloaded image 04/12
# Downloaded image 05/12
# Downloaded image 06/12
# Downloaded image 07/12
# Downloaded image 08/12
# Downloaded image 09/12
# Downloaded image 10/12
# Downloaded image 11/12
# Downloaded image 12/12
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506347.tif
# Image saved for building ID 1313506347
# Processing building ID 1313506348 with expanded bbox [-95.23227800000001, 41.014431015, -95.2321662, 41.014540085]
# Downloaded image 1/4
# Downloaded image 2/4
# Downloaded image 3/4
# Downloaded image 4/4
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506348.tif
# Image saved for building ID 1313506348
# Processing building ID 1313506349 with expanded bbox [-95.23246517, 41.014315610000004, -95.23234583, 41.01439959]
# Downloaded image 1/4
# Downloaded image 2/4
# Downloaded image 3/4
# Downloaded image 4/4
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506349.tif
# Image saved for building ID 1313506349
# Processing building ID 1313506350 with expanded bbox [-95.23209674, 41.014453675, -95.23196205999999, 41.014546625]
# Downloaded image 1/6
# Downloaded image 2/6
# Downloaded image 3/6
# Downloaded image 4/6
# Downloaded image 5/6
# Downloaded image 6/6
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506350.tif
# Image saved for building ID 1313506350
# Processing building ID 1313506351 with expanded bbox [-95.23178823500001, 41.014618625, -95.23167266499999, 41.014829875000004]
# Downloaded image 01/10
# Downloaded image 02/10
# Downloaded image 03/10
# Downloaded image 04/10
# Downloaded image 05/10
# Downloaded image 06/10
# Downloaded image 07/10
# Downloaded image 08/10
# Downloaded image 09/10
# Downloaded image 10/10
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506351.tif
# Image saved for building ID 1313506351
# Processing building ID 1313506352 with expanded bbox [-95.23195979, 41.01466928, -95.23182381000001, 41.01479512]
# Downloaded image 1/6
# Downloaded image 2/6
# Downloaded image 3/6
# Downloaded image 4/6
# Downloaded image 5/6
# Downloaded image 6/6
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506352.tif
# Image saved for building ID 1313506352
# Processing building ID 1313506353 with expanded bbox [-95.23210848, 41.014658655, -95.23198212, 41.014833245]
# Downloaded image 1/8
# Downloaded image 2/8
# Downloaded image 3/8
# Downloaded image 4/8
# Downloaded image 5/8
# Downloaded image 6/8
# Downloaded image 7/8
# Downloaded image 8/8
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506353.tif
# Image saved for building ID 1313506353
# Processing building ID 1313506354 with expanded bbox [-95.232259105, 41.014674015, -95.232138595, 41.014801285000004]
# Downloaded image 1/9
# Downloaded image 2/9
# Downloaded image 3/9
# Downloaded image 4/9
# Downloaded image 5/9
# Downloaded image 6/9
# Downloaded image 7/9
# Downloaded image 8/9
# Downloaded image 9/9
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506354.tif
# Image saved for building ID 1313506354
# Processing building ID 1313506355 with expanded bbox [-95.23179165, 41.014515545, -95.23166814999999, 41.014608755]
# Downloaded image 1/4
# Downloaded image 2/4
# Downloaded image 3/4
# Downloaded image 4/4
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506355.tif
# Image saved for building ID 1313506355
# Processing building ID 1313506356 with expanded bbox [-95.23180038, 41.01400837, -95.23166622, 41.014437629999996]
# Downloaded image 01/16
# Downloaded image 02/16
# Downloaded image 03/16
# Downloaded image 04/16
# Downloaded image 05/16
# Downloaded image 06/16
# Downloaded image 07/16
# Downloaded image 08/16
# Downloaded image 09/16
# Downloaded image 10/16
# Downloaded image 11/16
# Downloaded image 12/16
# Downloaded image 13/16
# Downloaded image 14/16
# Downloaded image 15/16
# Downloaded image 16/16
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506356.tif
# Image saved for building ID 1313506356
# Processing building ID 1313506357 with expanded bbox [-95.23198057500001, 41.013952405, -95.231777125, 41.014117895]
# Downloaded image 01/12
# Downloaded image 02/12
# Downloaded image 03/12
# Downloaded image 04/12
# Downloaded image 05/12
# Downloaded image 06/12
# Downloaded image 07/12
# Downloaded image 08/12
# Downloaded image 09/12
# Downloaded image 10/12
# Downloaded image 11/12
# Downloaded image 12/12
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506357.tif
# Image saved for building ID 1313506357
# Processing building ID 1313506358 with expanded bbox [-95.23213950499999, 41.013953225, -95.231982595, 41.014125475]
# Downloaded image 1/8
# Downloaded image 2/8
# Downloaded image 3/8
# Downloaded image 4/8
# Downloaded image 5/8
# Downloaded image 6/8
# Downloaded image 7/8
# Downloaded image 8/8
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506358.tif
# Image saved for building ID 1313506358
# Processing building ID 1313506359 with expanded bbox [-95.23242521499999, 41.013957885, -95.232279485, 41.014132215]
# Downloaded image 01/12
# Downloaded image 02/12
# Downloaded image 03/12
# Downloaded image 04/12
# Downloaded image 05/12
# Downloaded image 06/12
# Downloaded image 07/12
# Downloaded image 08/12
# Downloaded image 09/12
# Downloaded image 10/12
# Downloaded image 11/12
# Downloaded image 12/12
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506359.tif
# Image saved for building ID 1313506359
# Processing building ID 1313506360 with expanded bbox [-95.23261783000001, 41.013560049999995, -95.23246936999999, 41.01379015]
# Downloaded image 01/15
# Downloaded image 02/15
# Downloaded image 03/15
# Downloaded image 04/15
# Downloaded image 05/15
# Downloaded image 06/15
# Downloaded image 07/15
# Downloaded image 08/15
# Downloaded image 09/15
# Downloaded image 10/15
# Downloaded image 11/15
# Downloaded image 12/15
# Downloaded image 13/15
# Downloaded image 14/15
# Downloaded image 15/15
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506360.tif
# Image saved for building ID 1313506360
# Processing building ID 1313506361 with expanded bbox [-95.23251548500001, 41.013449805, -95.232289415, 41.013630895]
# Downloaded image 01/16
# Downloaded image 02/16
# Downloaded image 03/16
# Downloaded image 04/16
# Downloaded image 05/16
# Downloaded image 06/16
# Downloaded image 07/16
# Downloaded image 08/16
# Downloaded image 09/16
# Downloaded image 10/16
# Downloaded image 11/16
# Downloaded image 12/16
# Downloaded image 13/16
# Downloaded image 14/16
# Downloaded image 15/16
# Downloaded image 16/16
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506361.tif
# Image saved for building ID 1313506361
# Processing building ID 1313506362 with expanded bbox [-95.232519425, 41.01330254, -95.23224967499999, 41.01346426]
# Downloaded image 01/16
# Downloaded image 02/16
# Downloaded image 03/16
# Downloaded image 04/16
# Downloaded image 05/16
# Downloaded image 06/16
# Downloaded image 07/16
# Downloaded image 08/16
# Downloaded image 09/16
# Downloaded image 10/16
# Downloaded image 11/16
# Downloaded image 12/16
# Downloaded image 13/16
# Downloaded image 14/16
# Downloaded image 15/16
# Downloaded image 16/16
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506362.tif
# Image saved for building ID 1313506362
# Processing building ID 1313506363 with expanded bbox [-95.23260562, 41.013148605000005, -95.23239138, 41.013334895]
# Downloaded image 01/16
# Downloaded image 02/16
# Downloaded image 03/16
# Downloaded image 04/16
# Downloaded image 05/16
# Downloaded image 06/16
# Downloaded image 07/16
# Downloaded image 08/16
# Downloaded image 09/16
# Downloaded image 10/16
# Downloaded image 11/16
# Downloaded image 12/16
# Downloaded image 13/16
# Downloaded image 14/16
# Downloaded image 15/16
# Downloaded image 16/16
# Saving GeoTIFF. Please wait...
# Image saved to /content/drive/MyDrive/Madhu RA Work Folder/newdata/Single/building_1313506363.tif
# Image saved for building ID 1313506363
# Processing building ID 1313506364 with expanded bbox [-95.23230303999999, 41.01314223, -95.23211896000001, 41.01337077]
# Downloaded image 01/12
# Downloaded image 02/12
# Downloaded image 03/12
# Downloaded image 04/12
# Downloaded image 05/12
# Downloaded image 06/12
# Downloaded image 07/12
# Downloaded image 08/12
# Downloaded image 09/12
# Downloaded image 10/12
# Downloaded image 11/12
# Downloaded image 12/12
# Saving GeoTIFF. Please wait...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-874e41f4d859> in <cell line: 137>()
#     136
#     137 if __name__ == "__main__":
# --> 138     main()
#
# <ipython-input-2-874e41f4d859> in main()
#     112
#     113         # Download and resize the image
# --> 114         original_size, resized_size = download_and_resize_image(
#     115             image_path, bbox, zoom, source, output_size)
#     116
#
# <ipython-input-1-51636c186a01> in download_and_resize_image(image_path, bbox, zoom, source, output_size)
#       9     try:
#      10         #Download the image using the geographic bounding box
# ---> 11         tms_to_geotiff(output=image_path, bbox=bbox, zoom=zoom, source=source, overwrite=True)
#      12
#      13         #Open the downloaded image
#
# /usr/local/lib/python3.10/dist-packages/samgeo/common.py in tms_to_geotiff(output, bbox, zoom, resolution, source, crs, to_cog, return_image, overwrite, quiet, **kwargs)
#     657
#     658     try:
# --> 659         image = draw_tile(
#     660             source, south, west, north, east, zoom, output, quiet, **kwargs
#     661         )
#
# /usr/local/lib/python3.10/dist-packages/samgeo/common.py in draw_tile(source, lat0, lon0, lat1, lon1, zoom, filename, quiet, **kwargs)
#     650             band = gtiff.GetRasterBand(band + 1)
#     651             band.WriteArray(array)
# --> 652         gtiff.FlushCache()
#     653
#     654         if not quiet:
#
# /usr/local/lib/python3.10/dist-packages/osgeo/gdal.py in FlushCache(self, *args)
#    2560     def FlushCache(self, *args) -> "void":
#    2561         r"""FlushCache(Dataset self)"""
# -> 2562         return _gdal.Dataset_FlushCache(self, *args)
#    2563
#    2564     def AddBand(self, *args, **kwargs) -> "CPLErr":
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
import time
from math import radians, cos

def main():
    zoom = 22  # Adjust zoom level as needed
    source = "Satellite"

    # Bounding box expansion factor (e.g., 0.1 for 10% expansion)
    bbox_expansion_factor = 0.3  # Adjust this value to control the space around the building

    # Desired image height in pixels (you can adjust this)
    desired_image_height = 500  # pixels

    df = pd.read_csv('/content/drive/MyDrive/Madhu RA Work Folder/newdata/Buildings_USA.csv')

    output_base_dir = '/content/drive/MyDrive/Madhu RA Work Folder/newdata'

    # Dictionary to keep track of counts per class
    class_counts = {}
    max_images_per_class = 2000

    # Loop over each building in the DataFrame
    for index, row in df.iterrows():
        building_id = row['building_id']
        building_class = row['building_class']
        if pd.isnull(building_class) or building_class.lower() != 'industrial':
            continue  # Skip buildings that are not hospitals

        # Initialize count for this class if not already done
        if building_class not in class_counts:
            class_counts[building_class] = 0

        # Check if we have already downloaded the maximum number of images for this class
        if class_counts[building_class] >= max_images_per_class:
            continue  # Skip to next building

        # Get the corner coordinates from the CSV
        corner1_lat = row['corner1_lat']
        corner1_lon = row['corner1_lon']
        corner2_lat = row['corner2_lat']
        corner2_lon = row['corner2_lon']
        corner3_lat = row['corner3_lat']
        corner3_lon = row['corner3_lon']
        corner4_lat = row['corner4_lat']
        corner4_lon = row['corner4_lon']

        # Compute min and max latitudes and longitudes from the corners
        latitudes = [corner1_lat, corner2_lat, corner3_lat, corner4_lat]
        longitudes = [corner1_lon, corner2_lon, corner3_lon, corner4_lon]
        min_lat = min(latitudes)
        max_lat = max(latitudes)
        min_lon = min(longitudes)
        max_lon = max(longitudes)

        # Calculate the width and height of the bounding box in degrees
        width_deg = max_lon - min_lon
        height_deg = max_lat - min_lat

        # Expand the bounding box by the expansion factor
        min_lon_expanded = min_lon - (width_deg * bbox_expansion_factor / 2)
        max_lon_expanded = max_lon + (width_deg * bbox_expansion_factor / 2)
        min_lat_expanded = min_lat - (height_deg * bbox_expansion_factor / 2)
        max_lat_expanded = max_lat + (height_deg * bbox_expansion_factor / 2)

        # Calculate the center latitude for distance calculations
        center_lat = (min_lat_expanded + max_lat_expanded) / 2.0

        # Convert degrees to radians for trigonometric functions
        lat_rad = radians(center_lat)

        # Approximate meters per degree latitude and longitude
        meters_per_deg_lat = 111320  # meters per degree latitude is approximately constant
        meters_per_deg_lon = 111320 * cos(lat_rad)  # varies with latitude

        # Calculate physical width and height in meters
        width_meters = (max_lon_expanded - min_lon_expanded) * meters_per_deg_lon
        height_meters = (max_lat_expanded - min_lat_expanded) * meters_per_deg_lat

        # Calculate the aspect ratio
        aspect_ratio = width_meters / height_meters

        # Calculate the desired image width based on the aspect ratio
        desired_image_width = int(desired_image_height * aspect_ratio)

        # Ensure the width is at least 1 pixel
        desired_image_width = max(desired_image_width, 1)

        # Define the output image size
        output_size = (desired_image_width, desired_image_height)

        # Create expanded bbox
        bbox = [min_lon_expanded, min_lat_expanded, max_lon_expanded, max_lat_expanded]
        print(f"Processing building ID {building_id} with expanded bbox {bbox}")

        # Create the output directory for this class if it doesn't exist
        class_output_dir = os.path.join(output_base_dir, building_class)
        os.makedirs(class_output_dir, exist_ok=True)

        # Define the image file path using the building ID
        image_filename = f"building_{building_id}.tif"
        image_path = os.path.join(class_output_dir, image_filename)

        # Skip if the image already exists
        if os.path.exists(image_path):
            print(f"Image already exists for building ID {building_id}, skipping.")
            continue

        # Download and resize the image
        original_size, resized_size = download_and_resize_image(
            image_path, bbox, zoom, source, output_size)

        if original_size and resized_size:
            print(f"Image saved for building ID {building_id}")
            # Increment the count for this class
            class_counts[building_class] += 1
        else:
            print(f"Failed to download image for building ID {building_id}")

        # Check if we have reached the maximum images for this class
        if class_counts[building_class] >= max_images_per_class:
            print(f"Reached maximum images for class '{building_class}'")
            continue  # Continue to next building

        # Sleep to respect server rate limits
        time.sleep(1)

if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# Downloaded image 415/700
# Downloaded image 416/700
# Downloaded image 417/700
# Downloaded image 418/700
# Downloaded image 419/700
# Downloaded image 420/700
# Downloaded image 421/700
# Downloaded image 422/700
# Downloaded image 423/700
# Downloaded image 424/700
# Downloaded image 425/700
# Downloaded image 426/700
# Downloaded image 427/700
# Downloaded image 428/700
# Downloaded image 429/700
# Downloaded image 430/700
# Downloaded image 431/700
# Downloaded image 432/700
# Downloaded image 433/700
# Downloaded image 434/700
# Downloaded image 435/700
# Downloaded image 436/700
# Downloaded image 437/700
# Downloaded image 438/700
# Downloaded image 439/700
# Downloaded image 440/700
# Downloaded image 441/700
# Downloaded image 442/700
# Downloaded image 443/700
# Downloaded image 444/700
# Downloaded image 445/700
# Downloaded image 446/700
# Downloaded image 447/700
# Downloaded image 448/700
# Downloaded image 449/700
# Downloaded image 450/700
# Downloaded image 451/700
# Downloaded image 452/700
# Downloaded image 453/700
# Downloaded image 454/700
# Downloaded image 455/700
# Downloaded image 456/700
# Downloaded image 457/700
# Downloaded image 458/700
# Downloaded image 459/700
# Downloaded image 460/700
# Downloaded image 461/700
# Downloaded image 462/700
# Downloaded image 463/700
# Downloaded image 464/700
# Downloaded image 465/700
# Downloaded image 466/700
# Downloaded image 467/700
# Downloaded image 468/700
# Downloaded image 469/700
# Downloaded image 470/700
# Downloaded image 471/700
# Downloaded image 472/700
# Downloaded image 473/700
# Downloaded image 474/700
# Downloaded image 475/700
# Downloaded image 476/700
# Downloaded image 477/700
# Downloaded image 478/700
# Downloaded image 479/700
# Downloaded image 480/700
# Downloaded image 481/700
# Downloaded image 482/700
# Downloaded image 483/700
# Downloaded image 484/700
# Downloaded image 485/700
# Downloaded image 486/700
# Downloaded image 487/700
# Downloaded image 488/700
# Downloaded image 489/700
# Downloaded image 490/700
# Downloaded image 491/700
# Downloaded image 492/700
# Downloaded image 493/700
# Downloaded image 494/700
# Downloaded image 495/700
# Downloaded image 496/700
# Downloaded image 497/700
# Downloaded image 498/700
# Downloaded image 499/700
# Downloaded image 500/700
# Downloaded image 501/700
# Downloaded image 502/700
# Downloaded image 503/700
# Downloaded image 504/700
# Downloaded image 505/700
# Downloaded image 506/700
# Downloaded image 507/700
# Downloaded image 508/700
# Downloaded image 509/700
# Downloaded image 510/700
# Downloaded image 511/700
# Downloaded image 512/700
# Downloaded image 513/700
# Downloaded image 514/700
# Downloaded image 515/700
# Downloaded image 516/700
# Downloaded image 517/700
# Downloaded image 518/700
# Downloaded image 519/700
# Downloaded image 520/700
# Downloaded image 521/700
# Downloaded image 522/700
# Downloaded image 523/700
# Downloaded image 524/700
# Downloaded image 525/700
# Downloaded image 526/700
# Downloaded image 527/700
# Downloaded image 528/700
# Downloaded image 529/700
# Downloaded image 530/700
# Downloaded image 531/700
# Downloaded image 532/700
# Downloaded image 533/700
# Downloaded image 534/700
# Downloaded image 535/700
# Downloaded image 536/700
# Downloaded image 537/700
# Downloaded image 538/700
# Downloaded image 539/700
# Downloaded image 540/700
# Downloaded image 541/700
# Downloaded image 542/700
# Downloaded image 543/700
# Downloaded image 544/700
# Downloaded image 545/700
# Downloaded image 546/700
# Downloaded image 547/700
# Downloaded image 548/700
# Downloaded image 549/700
# Downloaded image 550/700
# Downloaded image 551/700
# Downloaded image 552/700
# Downloaded image 553/700
# Downloaded image 554/700
# Downloaded image 555/700
# Downloaded image 556/700
# Downloaded image 557/700
# Downloaded image 558/700
# Downloaded image 559/700
# Downloaded image 560/700
# Downloaded image 561/700
# Downloaded image 562/700
# Downloaded image 563/700
# Downloaded image 564/700
# Downloaded image 565/700
# Downloaded image 566/700
# Downloaded image 567/700
# Downloaded image 568/700
# Downloaded image 569/700
# Downloaded image 570/700
# Downloaded image 571/700
# Downloaded image 572/700
# Downloaded image 573/700
# Downloaded image 574/700
# Downloaded image 575/700
# Downloaded image 576/700
# Downloaded image 577/700
# Downloaded image 578/700
# Downloaded image 579/700
# Downloaded image 580/700
# Downloaded image 581/700
# Downloaded image 582/700
# Downloaded image 583/700
# Downloaded image 584/700
# Downloaded image 585/700
# Downloaded image 586/700
# Downloaded image 587/700
# Downloaded image 588/700
# Downloaded image 589/700
# Downloaded image 590/700
# Downloaded image 591/700
# Downloaded image 592/700
# Downloaded image 593/700
# Downloaded image 594/700
# Downloaded image 595/700
# Downloaded image 596/700
# Downloaded image 597/700
# Downloaded image 598/700
# Downloaded image 599/700
# Downloaded image 600/700
# Downloaded image 601/700
# Downloaded image 602/700
# Downloaded image 603/700
# Downloaded image 604/700
# Downloaded image 605/700
# Downloaded image 606/700
# Downloaded image 607/700
# Downloaded image 608/700
# Downloaded image 609/700
# Downloaded image 610/700
# Downloaded image 611/700
# Downloaded image 612/700
# Downloaded image 613/700
# Downloaded image 614/700
# Downloaded image 615/700
# Downloaded image 616/700
# Downloaded image 617/700
# Downloaded image 618/700
# Downloaded image 619/700
# Downloaded image 620/700
# Downloaded image 621/700
# Downloaded image 622/700
# Downloaded image 623/700
# Downloaded image 624/700
# Downloaded image 625/700
# Downloaded image 626/700
# Downloaded image 627/700
# Downloaded image 628/700
# Downloaded image 629/700
# Downloaded image 630/700
# Downloaded image 631/700
# Downloaded image 632/700
# Downloaded image 633/700
# Downloaded image 634/700
# Downloaded image 635/700
# Downloaded image 636/700
# Downloaded image 637/700
# Downloaded image 638/700
# Downloaded image 639/700
# Downloaded image 640/700
# Downloaded image 641/700
# Downloaded image 642/700
# Downloaded image 643/700
# Downloaded image 644/700
# Downloaded image 645/700
# Downloaded image 646/700
# Downloaded image 647/700
# Downloaded image 648/700
# Downloaded image 649/700
# Downloaded image 650/700
# Downloaded image 651/700
# Downloaded image 652/700
# Downloaded image 653/700
# Downloaded image 654/700
# Downloaded image 655/700
# Downloaded image 656/700
# Downloaded image 657/700
# Downloaded image 658/700
# Downloaded image 659/700
# Downloaded image 660/700
# Downloaded image 661/700
# Downloaded image 662/700
# Downloaded image 663/700
# Downloaded image 664/700
# Downloaded image 665/700
# Downloaded image 666/700
# Downloaded image 667/700
# Downloaded image 668/700
# Downloaded image 669/700
# Downloaded image 670/700
# Downloaded image 671/700
# Downloaded image 672/700
# Downloaded image 673/700
# Downloaded image 674/700
# Downloaded image 675/700
# Downloaded image 676/700
# Downloaded image 677/700
# Downloaded image 678/700
# Downloaded image 679/700
# Downloaded image 680/700
# Downloaded image 681/700
# Downloaded image 682/700
# Downloaded image 683/700
# Downloaded image 684/700
# Downloaded image 685/700
# Downloaded image 686/700
# Downloaded image 687/700
# Downloaded image 688/700
# Downloaded image 689/700
# Downloaded image 690/700
# Downloaded image 691/700
# Downloaded image 692/700
# Downloaded image 693/700
# Downloaded image 694/700
# Downloaded image 695/700
# Downloaded image 696/700
# Downloaded image 697/700
# Downloaded image 698/700
# Downloaded image 699/700
# Downloaded image 700/700
# Saving GeoTIFF. Please wait...
# Failed to download or resize image for bbox [-131.57331567, 55.128742745000004, -131.57126453, 55.130042355]. Error: 'NoneType' object has no attribute 'crop'
# Failed to download image for building ID 531902418
# Processing building ID 341362826 with expanded bbox [-87.385283735, 46.335640315000006, -87.383899365, 46.336521585]
# Downloaded image 001/272
# Downloaded image 002/272
# Downloaded image 003/272
# Downloaded image 004/272
# Downloaded image 005/272
# Downloaded image 006/272
# Downloaded image 007/272
# Downloaded image 008/272
# Downloaded image 009/272
# Downloaded image 010/272
# Downloaded image 011/272
# Downloaded image 012/272
# Downloaded image 013/272
# Downloaded image 014/272
# Downloaded image 015/272
# Downloaded image 016/272
# Downloaded image 017/272
# Downloaded image 018/272
# Downloaded image 019/272
# Downloaded image 31/54
# Downloaded image 32/54
# Downloaded image 33/54
# Downloaded image 34/54
# Downloaded image 35/54
# Downloaded image 36/54
# Downloaded image 37/54
# Downloaded image 38/54
# Downloaded image 39/54
# Downloaded image 40/54
# Downloaded image 41/54
# Downloaded image 42/54
# Downloaded image 43/54
# Downloaded image 44/54
# Downloaded image 45/54
# Downloaded image 46/54
# Downloaded image 47/54
# Downloaded image 48/54
# Downloaded image 49/54
# Downloaded image 50/54
# Downloaded image 51/54
# Downloaded image 52/54
# Downloaded image 53/54
# Downloaded image 54/54
# Saving GeoTIFF. Please wait...
# Failed to download or resize image for bbox [-87.385403565, 46.35342386, -87.384967935, 46.35387054]. Error: 'NoneType' object has no attribute 'crop'
# Failed to download image for building ID 341580749
# Processing building ID 341580750 with expanded bbox [-87.38525079, 46.354269974999994, -87.38411901, 46.354537125]
# Downloaded image 01/84
# Downloaded image 02/84
# Downloaded image 03/84
# Downloaded image 04/84
# Downloaded image 05/84
# Downloaded image 06/84
# Downloaded image 07/84
# Downloaded image 08/84
# Downloaded image 09/84
# Downloaded image 10/84
# Downloaded image 11/84
# Downloaded image 12/84
# Downloaded image 13/84
# Downloaded image 14/84
# Downloaded image 15/84
# Downloaded image 16/84
# Downloaded image 17/84
# Downloaded image 18/84
# Downloaded image 19/84
# Downloaded image 20/84
# Downloaded image 21/84
# Downloaded image 22/84
# Downloaded image 23/84
# Downloaded image 24/84
# Downloaded image 25/84
# Downloaded image 26/84
# Downloaded image 27/84
# Downloaded image 28/84
# Downloaded image 29/84
# Downloaded image 30/84
# Downloaded image 31/84
# Downloaded image 32/84
# Downloaded image 33/84
# Downloaded image 34/84
# Downloaded image 35/84
# Downloaded image 36/84
# Downloaded image 37/84
# Downloaded image 38/84
# Downloaded image 39/84
# Downloaded image 40/84
# Downloaded image 41/84
# Downloaded image 42/84
# Downloaded image 43/84
# Downloaded image 44/84
# Downloaded image 45/84
# Downloaded image 46/84
# Downloaded image 47/84
# Downloaded image 48/84
# Downloaded image 49/84
# Downloaded image 50/84
# Downloaded image 51/84
# Downloaded image 52/84
# Downloaded image 53/84
# Downloaded image 54/84
# Downloaded image 55/84
# Downloaded image 56/84
# Downloaded image 57/84
# Downloaded image 58/84
# Downloaded image 59/84
# Downloaded image 60/84
# Downloaded image 61/84
# Downloaded image 62/84
# Downloaded image 63/84
# Downloaded image 64/84
# Downloaded image 65/84
# Downloaded image 66/84
# Downloaded image 67/84
# Downloaded image 68/84
# Downloaded image 69/84
# Downloaded image 70/84
# Downloaded image 71/84
# Downloaded image 72/84
# Downloaded image 73/84
# Downloaded image 74/84
# Downloaded image 75/84
# Downloaded image 76/84
# Downloaded image 77/84
# Downloaded image 78/84
# Downloaded image 79/84
# Downloaded image 80/84
# Downloaded image 81/84
# Downloaded image 82/84
# Downloaded image 83/84
# Downloaded image 84/84
# Saving GeoTIFF. Please wait...
# Failed to download or resize image for bbox [-87.38525079, 46.354269974999994, -87.38411901, 46.354537125]. Error: 'NoneType' object has no attribute 'crop'
# Image already exists for building ID 333278861, skipping.
# Processing building ID 333278882 with expanded bbox [-76.44152213, 37.01195794, -76.44132947, 37.01215866]
# Image already exists for building ID 333278882, skipping.
# Processing building ID 333278885 with expanded bbox [-76.43932007, 37.008423035, -76.43917213, 37.008671465]
# Image already exists for building ID 333278885, skipping.
# Processing building ID 333278944 with expanded bbox [-76.41654150000001, 37.00182901, -76.4158681, 37.00233679]
# Image already exists for building ID 333278944, skipping.
# Processing building ID 333279037 with expanded bbox [-76.441605295, 37.011927879999995, -76.441421605, 37.012118720000004]
# Image already exists for building ID 333279037, skipping.
# Processing building ID 333279041 with expanded bbox [-76.41714184499999, 37.003072485000004, -76.416886655, 37.003262414999995]
# Image already exists for building ID 333279041, skipping.
# Processing building ID 333279042 with expanded bbox [-76.41673058, 37.00286727, -76.41640401999999, 37.003195129999995]
# Image already exists for building ID 333279042, skipping.
# Processing building ID 333279047 with expanded bbox [-76.416863765, 37.003182724999995, -76.416487935, 37.003531775000006]
# Image already exists for building ID 333279047, skipping.
# Processing building ID 333279474 with expanded bbox [-76.43713410500001, 37.00459671, -76.43680039499999, 37.00478209]
# Image already exists for building ID 333279474, skipping.
# Processing building ID 333279475 with expanded bbox [-76.43738705, 37.004673925, -76.43604415, 37.005363575000004]
# Image already exists for building ID 333279475, skipping.
# Processing building ID 333279478 with expanded bbox [-76.43702708, 37.00552515, -76.43653152, 37.00584365]
# Image already exists for building ID 333279478, skipping.
# Processing building ID 333279479 with expanded bbox [-76.43861391499999, 37.00673442, -76.437768785, 37.00730798]
# Image already exists for building ID 333279479, skipping.
# Processing building ID 333279525 with expanded bbox [-76.438964925, 37.009435194999995, -76.43875757500001, 37.009612905000004]
# Image already exists for building ID 333279525, skipping.
# Processing building ID 333279605 with expanded bbox [-76.44161110499999, 37.00999442, -76.440388195, 37.01091638]
# Image already exists for building ID 333279605, skipping.
# Processing building ID 333279625 with expanded bbox [-76.44170849999999, 37.01189883, -76.4415213, 37.01208837]
# Image already exists for building ID 333279625, skipping.
# Processing building ID 333280170 with expanded bbox [-76.441829455, 37.011867095, -76.44161144499999, 37.012086405]
# Image already exists for building ID 333280170, skipping.
# Processing building ID 333280271 with expanded bbox [-76.43853154, 37.005302289999996, -76.43724246, 37.00640911]
# Image already exists for building ID 333280271, skipping.
# Processing building ID 333280329 with expanded bbox [-76.44735946, 37.01781960500001, -76.44724454, 37.017925295]
# Image already exists for building ID 333280329, skipping.
# Processing building ID 333280336 with expanded bbox [-76.447294545, 37.01787054, -76.447179755, 37.01796726]
# Image already exists for building ID 333280336, skipping.
# Processing building ID 333280435 with expanded bbox [-76.4418558, 37.012081235, -76.441796, 37.012124265000004]
# Image already exists for building ID 333280435, skipping.
# Processing building ID 333280438 with expanded bbox [-76.438993055, 37.009495035, -76.43895444500001, 37.009527665]
# Image already exists for building ID 333280438, skipping.
# Processing building ID 333280487 with expanded bbox [-76.43982774, 37.00780339, -76.43976586000001, 37.00785201]
# Image already exists for building ID 333280487, skipping.
# Processing building ID 333280758 with expanded bbox [-76.44535497999999, 37.01542179, -76.44529882, 37.01546781]
# Image already exists for building ID 333280758, skipping.
# Processing building ID 333280762 with expanded bbox [-76.447215355, 37.017789985, -76.447168945, 37.017829115]
# Image already exists for building ID 333280762, skipping.
# Processing building ID 333280876 with expanded bbox [-76.43923629, 37.00895448, -76.43911071000001, 37.00910632]
# Image already exists for building ID 333280876, skipping.
# Processing building ID 333280892 with expanded bbox [-76.439323035, 37.00893809, -76.43921006500001, 37.00908551]
# Image already exists for building ID 333280892, skipping.
# Processing building ID 333281067 with expanded bbox [-76.43934217500001, 37.0093829, -76.439159525, 37.0094713]
# Image already exists for building ID 333281067, skipping.
# Processing building ID 333281291 with expanded bbox [-76.43917268999999, 37.008425509999995, -76.43894051000001, 37.008691490000004]
# Image already exists for building ID 333281291, skipping.
# Processing building ID 965961925 with expanded bbox [-91.37199048000001, 40.39713208, -91.36989851999999, 40.40030772]
# Image already exists for building ID 965961925, skipping.
# Processing building ID 965962755 with expanded bbox [-91.37454534000001, 40.395456149999994, -91.37252045999999, 40.395998250000005]
# Image already exists for building ID 965962755, skipping.
# Processing building ID 965962757 with expanded bbox [-91.37388091, 40.395646215, -91.37303929000001, 40.396033485]
# Image already exists for building ID 965962757, skipping.
# Processing building ID 476052577 with expanded bbox [-92.373352285, 30.207179315, -92.37251781500001, 30.207722585]
# Image already exists for building ID 476052577, skipping.
# Processing building ID 661561613 with expanded bbox [-84.03021611, 42.150629845, -84.02838909, 42.151804655]
# Image already exists for building ID 661561613, skipping.
# Processing building ID 661561615 with expanded bbox [-84.02770458, 42.151882910000005, -84.02686062, 42.153188889999996]
# Image already exists for building ID 661561615, skipping.
# Processing building ID 661561616 with expanded bbox [-84.02921507, 42.15252212, -84.02863033, 42.15306188]
# Image already exists for building ID 661561616, skipping.
# Processing building ID 661561618 with expanded bbox [-84.047634745, 42.14763757, -84.04587935500001, 42.14937463]
# Image already exists for building ID 661561618, skipping.
# Processing building ID 661561619 with expanded bbox [-84.04908411000001, 42.14797755, -84.04712968999999, 42.14908645]
# Image already exists for building ID 661561619, skipping.
# Processing building ID 690038456 with expanded bbox [-84.074335365, 42.14442829, -84.072565935, 42.14558711]
# Image already exists for building ID 690038456, skipping.
# Processing building ID 745003873 with expanded bbox [-84.026592625, 42.14977088, -84.026156475, 42.15014372]
# Image already exists for building ID 745003873, skipping.
# Processing building ID 745012820 with expanded bbox [-84.03193807, 42.14715328, -84.03170693, 42.14735712]
# Image already exists for building ID 745012820, skipping.
# Processing building ID 601413662 with expanded bbox [-95.7363479, 31.69464382, -95.7314599, 31.70123898]
# Image already exists for building ID 601413662, skipping.
# Processing building ID 295764358 with expanded bbox [-111.841229145, 39.723489655, -111.83933335500001, 39.725208645]
# Image already exists for building ID 295764358, skipping.
# Processing building ID 295764359 with expanded bbox [-111.807798315, 39.715912540000005, -111.80728598500001, 39.71630826]
# Image already exists for building ID 295764359, skipping.
# Processing building ID 547135073 with expanded bbox [-85.68203668, 42.23809874, -85.67939352, 42.23985686]
# Image already exists for building ID 547135073, skipping.
# Processing building ID 1036323629 with expanded bbox [-85.66740861, 42.374952085, -85.66711039, 42.375662015]
# Image already exists for building ID 1036323629, skipping.
# Processing building ID 1010258655 with expanded bbox [-84.86060400000001, 33.623526049999995, -84.860474, 33.62364695]
# Image already exists for building ID 1010258655, skipping.
# Processing building ID 1010258692 with expanded bbox [-84.8608469, 33.623510849999995, -84.86055309999999, 33.62366815]
# Image already exists for building ID 1010258692, skipping.
# Processing building ID 67265954 with expanded bbox [-88.06503643500001, 41.740915709999996, -88.06454126499999, 41.74197729]
# Image already exists for building ID 67265954, skipping.
# Processing building ID 67266113 with expanded bbox [-88.066167855, 41.74321267, -88.065351845, 41.74365493]
# Image already exists for building ID 67266113, skipping.
# Processing building ID 67266114 with expanded bbox [-88.064779495, 41.742902300000004, -88.06404720500001, 41.7430167]
# Image already exists for building ID 67266114, skipping.
# Processing building ID 67266130 with expanded bbox [-88.06462387500001, 41.743123855, -88.063752225, 41.743815845]
# Image already exists for building ID 67266130, skipping.
# Processing building ID 67266144 with expanded bbox [-88.06488037, 41.743788085, -88.06448283, 41.744100214999996]
# Image already exists for building ID 67266144, skipping.
# Processing building ID 67266145 with expanded bbox [-88.06519467, 41.74329267, -88.06449033, 41.743630929999995]
# Image already exists for building ID 67266145, skipping.
# Processing building ID 67266146 with expanded bbox [-88.0662088, 41.742885285, -88.06559519999999, 41.743077815]
# Image already exists for building ID 67266146, skipping.
# Processing building ID 32896790 with expanded bbox [-84.354090565, 39.279269365, -84.352292535, 39.279951735000004]
# Image already exists for building ID 32896790, skipping.
# Processing building ID 32896792 with expanded bbox [-84.352598655, 39.279039635, -84.350797245, 39.279724865]
# Image already exists for building ID 32896792, skipping.
# Processing building ID 32896795 with expanded bbox [-84.35176101, 39.27811808, -84.35032659, 39.27877172]
# Image already exists for building ID 32896795, skipping.
# Processing building ID 32896797 with expanded bbox [-84.350222835, 39.27704343, -84.348542065, 39.27785177]
# Image already exists for building ID 32896797, skipping.
# Processing building ID 32896822 with expanded bbox [-84.35025050499999, 39.27561537, -84.34870779500001, 39.27612003]
# Image already exists for building ID 32896822, skipping.
# Processing building ID 32896823 with expanded bbox [-84.351430385, 39.27546216, -84.350863715, 39.27656144]
# Image already exists for building ID 32896823, skipping.
# Processing building ID 32896827 with expanded bbox [-84.353558705, 39.275393155, -84.35267899499999, 39.276625945]
# Image already exists for building ID 32896827, skipping.
# Processing building ID 32896829 with expanded bbox [-84.354916675, 39.274594289999996, -84.35382402500001, 39.27689191]
# Image already exists for building ID 32896829, skipping.
# Processing building ID 32896837 with expanded bbox [-84.35365280500001, 39.27431967, -84.35313449499999, 39.27516233]
# Image already exists for building ID 32896837, skipping.
# Processing building ID 32896841 with expanded bbox [-84.352627955, 39.27461969, -84.352207145, 39.27513371]
# Image already exists for building ID 32896841, skipping.
# Processing building ID 32896842 with expanded bbox [-84.351989355, 39.274131170000004, -84.35139434499999, 39.27523383]
# Image already exists for building ID 32896842, skipping.
# Processing building ID 32896845 with expanded bbox [-84.35158254, 39.27644577, -84.35054826, 39.27671903]
# Image already exists for building ID 32896845, skipping.
# Processing building ID 32896854 with expanded bbox [-84.351259115, 39.276896125, -84.35052578499999, 39.277284175]
# Image already exists for building ID 32896854, skipping.
# Processing building ID 32896864 with expanded bbox [-84.35205967, 39.276831945, -84.35163353, 39.277478955]
# Image already exists for building ID 32896864, skipping.
# Processing building ID 32896865 with expanded bbox [-84.352613165, 39.276778685, -84.352185335, 39.277426215000006]
# Image already exists for building ID 32896865, skipping.
# Processing building ID 32896866 with expanded bbox [-84.35334317, 39.27690897, -84.35271423, 39.27775683]
# Image already exists for building ID 32896866, skipping.
# Processing building ID 32896867 with expanded bbox [-84.354461635, 39.277006705, -84.35329826499999, 39.277757195]
# Image already exists for building ID 32896867, skipping.
# Processing building ID 32896869 with expanded bbox [-84.35451285, 39.277763825, -84.35328695, 39.278510675]
# Image already exists for building ID 32896869, skipping.
# Processing building ID 32896874 with expanded bbox [-84.35313618, 39.27818701, -84.35271602, 39.27914979]
# Image already exists for building ID 32896874, skipping.
# Processing building ID 32896877 with expanded bbox [-84.35228869000001, 39.27782253, -84.35166391, 39.27853467]
# Image already exists for building ID 32896877, skipping.
# Processing building ID 32896883 with expanded bbox [-84.35005319, 39.277886945000006, -84.34935301, 39.278263554999995]
# Image already exists for building ID 32896883, skipping.
# Processing building ID 32896884 with expanded bbox [-84.34991888, 39.278537125, -84.34921012, 39.278987574999995]
# Image already exists for building ID 32896884, skipping.
# Processing building ID 32896887 with expanded bbox [-84.35090859, 39.277766279999994, -84.35049441000001, 39.27799872]
# Image already exists for building ID 32896887, skipping.
# Processing building ID 32896889 with expanded bbox [-84.35091829, 39.278878945, -84.35022851000001, 39.279239954999994]
# Image already exists for building ID 32896889, skipping.
# Processing building ID 32896893 with expanded bbox [-84.34951263500001, 39.27913576, -84.349108465, 39.27950184]
# Image already exists for building ID 32896893, skipping.
# Processing building ID 32896895 with expanded bbox [-84.34932205, 39.27864684, -84.34859795, 39.279029560000005]
# Image already exists for building ID 32896895, skipping.
# Processing building ID 32897038 with expanded bbox [-84.3516504, 39.28406472499999, -84.3508418, 39.284962375000006]
# Image already exists for building ID 32897038, skipping.
# Processing building ID 32897042 with expanded bbox [-84.34670084999999, 39.284199835, -84.34606775, 39.285204865]
# Image already exists for building ID 32897042, skipping.
# Processing building ID 32897043 with expanded bbox [-84.34761569, 39.28391952, -84.34673350999999, 39.28513268]
# Image already exists for building ID 32897043, skipping.
# Processing building ID 32897045 with expanded bbox [-84.348766205, 39.2842221, -84.347904695, 39.2851529]
# Image already exists for building ID 32897045, skipping.
# Processing building ID 32897046 with expanded bbox [-84.3461647, 39.284086435, -84.3455979, 39.284706665]
# Image already exists for building ID 32897046, skipping.
# Processing building ID 32897312 with expanded bbox [-84.35681363, 39.278206475000005, -84.35553417, 39.279308225]
# Image already exists for building ID 32897312, skipping.
