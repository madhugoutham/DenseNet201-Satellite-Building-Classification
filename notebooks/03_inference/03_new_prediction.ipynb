# %%
# %pip install tensorflow keras numpy pandas matplotlib scikit-learn keras-tuner building_footprint_segmentation
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Collecting building_footprint_segmentation
#   Downloading building_footprint_segmentation-0.2.4-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.6 MB/s eta 0:00:00
# Downloading building_footprint_segmentation-0.2.4-py3-none-any.whl (35 kB)
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, building_footprint_segmentation, keras-tuner
# Successfully installed building_footprint_segmentation-0.2.4 keras-tuner-1.4.7 kt-legacy-1.0.5

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.densenet import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array

# Additional imports for result visualization
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Function to classify a single image
def classify_image(image_path, classification_model, class_labels):
    try:
        # Load the image
        image = cv2.imread(image_path)
        if image is None:
            raise ValueError(f"Error reading image {image_path}")

        # Convert to RGB
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # Resize to match the input size of the classifier
        image_resized = cv2.resize(image, (224, 224))

        # Convert to array and preprocess
        image_array = img_to_array(image_resized)
        image_array = np.expand_dims(image_array, axis=0)
        image_array = preprocess_input(image_array)

        # Predict using the classification model
        predictions = classification_model.predict(image_array)
        probabilities = predictions[0]
        top_class_index = np.argmax(probabilities)
        top_class = class_labels[top_class_index]
        probability = probabilities[top_class_index]

        return top_class, probability
    except Exception as e:
        print(f"Failed to classify {os.path.basename(image_path)}: {e}")
        return None, None

# Process each image: classify it and store results
def process_single_image(image_path, actual_class, classification_model, class_labels, visualize=False):
    try:
        # Classify the image
        predicted_class, probability = classify_image(image_path, classification_model, class_labels)

        if predicted_class is None:
            return False, None  # Classification failed

        # Print the classification result
        print(f"Image: {os.path.basename(image_path)} | Predicted: {predicted_class} ({probability:.4f}) | Actual: {actual_class}")

        # Determine if the prediction is correct
        correct = (predicted_class == actual_class)

        # Visualization
        if visualize:
            image = cv2.imread(image_path)
            if image is not None:
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                plt.figure(figsize=(6, 6))
                plt.imshow(image)
                plt.title(f"Predicted: {predicted_class} ({probability:.2f})\nActual: {actual_class}")
                plt.axis('off')
                plt.show()

        return correct, predicted_class
    except Exception as e:
        print(f"Failed to process {os.path.basename(image_path)}: {e}")
        return False, None

# Main function to process all images in the class folders
def process_images_in_folders(data_folder, classification_model, class_labels, visualize=False):
    total_correct = 0
    total_predictions = 0

    # Initialize per-class accuracy counts
    correct_predictions_per_class = {class_name: 0 for class_name in class_labels}
    total_predictions_per_class = {class_name: 0 for class_name in class_labels}

    # Lists to collect actual and predicted labels for confusion matrix
    y_true = []
    y_pred = []

    # Get list of class folders
    class_folders = [os.path.join(data_folder, d) for d in os.listdir(data_folder)
                     if os.path.isdir(os.path.join(data_folder, d))]

    # Collect all image paths and their actual classes with random sampling
    image_paths = []
    for class_folder in class_folders:
        class_name = os.path.basename(class_folder)
        images_in_class = [os.path.join(class_folder, f) for f in os.listdir(class_folder)
                           if f.lower().endswith(('.tif', '.jpg', '.png', '.jpeg'))]
        if len(images_in_class) > 20:
            selected_images = random.sample(images_in_class, 20)
        else:
            selected_images = images_in_class  # If less than 20 images, take all
        for img_path in selected_images:
            image_paths.append((img_path, class_name))

    # Shuffle image paths
    random.shuffle(image_paths)

    # Process images sequentially
    for image_path, actual_class in tqdm(image_paths, desc="Processing Images"):
        try:
            correct, predicted_class = process_single_image(
                image_path, actual_class, classification_model, class_labels, visualize=visualize)

            if predicted_class is not None:
                total_predictions += 1
                if correct:
                    total_correct += 1
                    correct_predictions_per_class[actual_class] += 1
                total_predictions_per_class[actual_class] += 1

                # Collect labels for confusion matrix
                y_true.append(actual_class)
                y_pred.append(predicted_class)
        except Exception as e:
            print(f"Failed to process {image_path}: {e}")

    # Calculate overall accuracy
    if total_predictions > 0:
        accuracy = (total_correct / total_predictions) * 100
    else:
        accuracy = 0.0

    print(f"\nTotal correct predictions: {total_correct}")
    print(f"Total predictions: {total_predictions}")
    print(f"Overall Accuracy: {accuracy:.2f}%")

    # Calculate and print per-class accuracy
    print("\nAccuracy per class:")
    for class_name in class_labels:
        correct = correct_predictions_per_class[class_name]
        total = total_predictions_per_class[class_name]
        if total > 0:
            class_accuracy = (correct / total) * 100
            print(f"{class_name}: {class_accuracy:.2f}% ({correct}/{total})")
        else:
            print(f"{class_name}: No predictions.")

    # Generate confusion matrix and classification report
    if y_true and y_pred:
        # Generate confusion matrix
        cm = confusion_matrix(y_true, y_pred, labels=class_labels)
        plt.figure(figsize=(10, 7))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                    xticklabels=class_labels, yticklabels=class_labels)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        plt.show()

        # Print classification report
        print("\nClassification Report:")
        print(classification_report(y_true, y_pred, labels=class_labels))

        # Analyze misclassifications
        print("\nMisclassified Samples:")
        misclassified = [(true, pred) for true, pred in zip(y_true, y_pred) if true != pred]
        for actual, predicted in misclassified:
            print(f'Actual: {actual}, Predicted: {predicted}')
    else:
        print("No predictions to generate confusion matrix and classification report.")

if __name__ == "__main__":
    # Data directory containing class folders
    data_folder = r'/content/drive/MyDrive/ML/Model/val'  # Update the path to your data folder

    # Define class labels (ensure these are in the correct order corresponding to your model's output)
    class_labels = ['Commercial', 'High', 'Hospital', 'Industrial', 'Multi', 'School', 'Single']  # Replace with your actual class names

    # Load the pre-trained classification model
    classification_model_path = r"/content/drive/MyDrive/Madhu RA Work Folder/Densenet201_combined_2.h5"  # Update the path to your model

    # Load the classification model
    try:
        classification_model = load_model(classification_model_path)
        print("Classification model loaded successfully.")
    except Exception as e:
        print(f"Error loading classification model: {e}")
        exit(1)

    # Set to True to visualize all images
    visualize = True  # Set to False to disable visualization

    # Process all images in the data folder
    process_images_in_folders(
        data_folder,
        classification_model,
        class_labels,
        visualize=visualize
    )
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import os
import hashlib
import logging

# Configure logging for duplicate checking
logging.basicConfig(
    filename='duplicate_check.log',
    level=logging.INFO,
    format='%(asctime)s:%(levelname)s:%(message)s'
)
existing_train_dir = '/content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2'
new_data_dir = '/content/drive/MyDrive/ML/Model/val'
t_data_dir = '/content/drive/MyDrive/ML/Model/test'
# Example using imagehash
from PIL import Image
import imagehash

def find_duplicate_images_perceptual(data_directories):
    hash_dict = {}
    duplicates = []
    total_images = 0

    for data_directory in data_directories:
        if not os.path.isdir(data_directory):
            logging.warning(f"Data directory '{data_directory}' does not exist. Skipping.")
            continue
        for root, dirs, files in os.walk(data_directory):
            for filename in files:
                if filename.lower().endswith(('.tif', '.tiff', '.jpg', '.jpeg', '.png', '.bmp', '.gif')):
                    filepath = os.path.join(root, filename)
                    total_images += 1
                    try:
                        image = Image.open(filepath)
                        filehash = str(imagehash.phash(image))
                        if filehash in hash_dict:
                            duplicates.append((filepath, hash_dict[filehash]))
                            logging.info(f"Duplicate found: {filepath} and {hash_dict[filehash]}")
                        else:
                            hash_dict[filehash] = filepath
                    except Exception as e:
                        logging.error(f"Error processing file {filepath}: {e}")

    print(f"Total images scanned: {total_images}")
    print(f"Total duplicates found: {len(duplicates)}")

    if duplicates:
        print("\nList of duplicate images:")
        for dup in duplicates:
            print(f"Duplicate pair:\n  {dup[0]}\n  {dup[1]}\n")
    else:
        print("No duplicate images found.")

    return duplicates

if __name__ == "__main__":
    # Specify your data directories
    train_dirs = [existing_train_dir, new_data_dir, t_data_dir]

    print("Checking for duplicate images in the dataset...")
    logging.info("Starting duplicate image check.")
    duplicates = find_duplicate_images_perceptual(train_dirs)
    logging.info("Duplicate image check completed.")
# Out:
# Checking for duplicate images in the dataset...
# Total images scanned: 1676
# Total duplicates found: 133
#
# List of duplicate images:
# Duplicate pair:
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/37.775766_-97.410278_IN_KS_244.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/37.782362_-97.409057_IN_KS_245.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Hospital/41.741104_72.198011_HL_CT_183.tif.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/41.741104_72.198011_HL_CT_183.tif.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Hospital/40.182136_105.126654_HL_CO_148.tif.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/40.182136_105.126654_HL_CO_148.tif.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Hospital/41.111597_73.422624_HL_CT_187.tif.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/41.111597_73.422624_HL_CT_187.tif.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Hospital/36.578902_121.913129_HL_CA_106.tif.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/36.578902_121.913129_HL_CA_106.tif.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Hospital/32.516775_110.887300_HL_AZ_70.tif.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/32.516775_110.887300_HL_AZ_70.tif.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Hospital/33.286845_111.752527_HL_AZ_58.tif.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/33.286845_111.752527_HL_AZ_58.tif.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Hospital/32.682747_114.635383_HL_AZ_50.tif.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/32.682747_114.635383_HL_AZ_50.tif.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Hospital/33.659689_112.372506_HL_AZ_63.tif.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/33.659689_112.372506_HL_AZ_63.tif.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Hospital/47.491601_111.260968_MT__855.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/47.491601_111.260968_MT__855.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Hospital/38.645631_90.446253_MO_HL_825.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/38.645631_90.446253_MO_HL_825.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Commercial/37.794875_-122.421346_CO_CA_299.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/37.794875_-122.421346_CO_CA_299.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Commercial/34.144891_-118.762877_CO_CA_268.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/34.144891_-118.762877_CO_CA_268.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Commercial/37.784037_-122.398314_CO__245.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/37.784037_-122.398314_CO__245.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Commercial/45.174525_-67.275604_CO_ME_133.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/45.174525_-67.275604_CO_ME_133.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Commercial/39.024795_-77.138252_CO_MD_103.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/39.024795_-77.138252_CO_MD_103.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Commercial/33.903113_-118.394727_CO_CA_68.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/33.903113_-118.394727_CO_CA_68.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Commercial/40.722040_-74.003752_CO_NY_27.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/40.722040_-74.003752_CO_NY_27.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Commercial/32.732584_-117.174566_CO_CA_56.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/32.732584_-117.174566_CO_CA_56.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Commercial/34.068551_-118.400034_CO_CA_4.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/34.068551_-118.400034_CO_CA_4.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Commercial/33.801642_-84.392508_CO_GA_339.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/33.801642_-84.392508_CO_GA_339.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/High/180__40.766192_-73.952379_MU_NY_180.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/180__40.766192_-73.952379_MU_NY_180.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/High/39.948356_-75.169869_PA_HB_201.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/39.948356_-75.169869_PA_HB_201.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/High/39.954058_-75.171942_PA_HB_190.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/39.954058_-75.171942_PA_HB_190.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/High/33.833140_-84.385378_GA_HB_49.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/33.833140_-84.385378_GA_HB_49.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/High/25.792642_-80.187129_FL_HB_108.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/25.792642_-80.187129_FL_HB_108.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/High/40.764643_-73.979671_NY_HB_40.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/40.764643_-73.979671_NY_HB_40.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/High/40.765245_-73.979589_NY_HB_39.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/40.765245_-73.979589_NY_HB_39.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/High/40.762187_-73.968037_NY_HB_28.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/40.762187_-73.968037_NY_HB_28.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/High/40.749098_-73.985624_NY_HB_4.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/40.749098_-73.985624_NY_HB_4.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/High/40.759453_-73.965844_NY_HB_7.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/40.759453_-73.965844_NY_HB_7.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/School/29.823484_95.546276_SC_TX_277.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/29.823484_95.546276_SC_TX_277.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/School/29.414561_98.444283_SC_TX_287.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/29.414561_98.444283_SC_TX_287.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/School/32.791464_96.866047_SC_TX_262.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/32.791464_96.866047_SC_TX_262.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/School/32.708722_97.281929_SC_TX_263.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/32.708722_97.281929_SC_TX_263.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/School/32.272983_95.278057_SC_TX_266.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/32.272983_95.278057_SC_TX_266.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/School/36.126578_86.786768_SC_TN_176.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/36.126578_86.786768_SC_TN_176.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/School/35.084175_90.015831_SC_TN_152.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/35.084175_90.015831_SC_TN_152.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/School/34.155701_118.830808_SC_CA_109.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/34.155701_118.830808_SC_CA_109.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/School/18.217491_65.649565_SC_PR_122.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/18.217491_65.649565_SC_PR_122.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/School/47.361426_94.307328_SC_MN_102.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/47.361426_94.307328_SC_MN_102.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Multi/4__33.850772_-84.382708_MU_GA_4.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/4__33.850772_-84.382708_MU_GA_4.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Multi/371__34.052616_-118.403097_MU_CA_371.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/371__34.052616_-118.403097_MU_CA_371.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Multi/362__34.072863_-118.347776_MU_CA_362.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/362__34.072863_-118.347776_MU_CA_362.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Multi/355__36.093405_-86.823023_MU__355.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/355__36.093405_-86.823023_MU__355.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Multi/85__33.817659_-84.391924_MU_GA_85.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/85__33.817659_-84.391924_MU_GA_85.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Multi/347__36.159099_-86.774663_MU__347.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/347__36.159099_-86.774663_MU__347.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Multi/350__36.129211_-86.817985_MU__350.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/350__36.129211_-86.817985_MU__350.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Multi/330__33.767412_-118.422011_MU__330.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/330__33.767412_-118.422011_MU__330.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Multi/334__33.764838_-118.403845_MU__334.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/334__33.764838_-118.403845_MU__334.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Multi/311__37.778036_-122.404631_MU__311.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/311__37.778036_-122.404631_MU__311.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Industrial/33.783241_-84.421947_IN_GA_71.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/33.783241_-84.421947_IN_GA_71.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Industrial/33.809488_-84.352843_IN_GA_74.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/33.809488_-84.352843_IN_GA_74.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Industrial/41.130101_-78.776955_IN_PA_274.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/41.130101_-78.776955_IN_PA_274.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Industrial/44.872982_-98.519272_IN_SD_289.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/44.872982_-98.519272_IN_SD_289.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Industrial/45.269084_-123.018050_IN_OR_270.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/45.269084_-123.018050_IN_OR_270.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Industrial/38.991644_-117.470911_IN_NV_189.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/38.991644_-117.470911_IN_NV_189.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Industrial/41.241698_-95.996175_IN_NE_188.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/41.241698_-95.996175_IN_NE_188.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Industrial/41.830595_-89.806817_IN_IL_152.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/41.830595_-89.806817_IN_IL_152.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Industrial/43.191561_-112.534992_IN_ID_142.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/43.191561_-112.534992_IN_ID_142.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Industrial/42.011823_-111.856597_IN_ID_145.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/42.011823_-111.856597_IN_ID_145.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Single/41.235966_-95.987532_NE_SU_1047.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Single/41.235966_-95.987532_NE_SU_1047.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Single/36.027973_-115.112746_NV_SU_1093.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Single/36.027973_-115.112746_NV_SU_1093.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Single/25.760075_-80.211659_FL_SU_907.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Single/25.760075_-80.211659_FL_SU_907.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Single/25.761806_-80.212140_FL_SU_910.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Single/25.761806_-80.212140_FL_SU_910.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Single/25.782399_-80.211668_FL_SU_894.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Single/25.782399_-80.211668_FL_SU_894.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Single/41.055461_-73.488924_CT_SU_867.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Single/41.055461_-73.488924_CT_SU_867.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Single/25.821751_-80.179267_FL_SU_899.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Single/25.821751_-80.179267_FL_SU_899.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Single/41.113899_-73.495388_CT_SU_868.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Single/41.113899_-73.495388_CT_SU_868.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Single/41.224987_-96.174950_NE_SU_861.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Single/41.224987_-96.174950_NE_SU_861.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/val/Single/19.496961_-155.912186_HI_SU_817.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Single/19.496961_-155.912186_HI_SU_817.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Industrial/41.742140_-89.829057_IN_IL_161.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/41.742140_-89.829057_IN_IL_161.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Industrial/41.794180_-89.807211_IN_IL_153.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/41.794180_-89.807211_IN_IL_153.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Industrial/36.033077_-115.086511_IN_NV_201.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/36.033077_-115.086511_IN_NV_201.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Industrial/33.778314_-84.365285_IN_GA_8.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/33.778314_-84.365285_IN_GA_8.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Industrial/33.822322_-84.457246_IN_GA_5.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/33.822322_-84.457246_IN_GA_5.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Industrial/33.812489_-84.449022_IN_GA_20.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/33.812489_-84.449022_IN_GA_20.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Industrial/39.607697_-75.697050_DE_IN_930.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/39.607697_-75.697050_DE_IN_930.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Industrial/39.735068_-75.545082_DE_IN_912.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/39.735068_-75.545082_DE_IN_912.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Industrial/39.656506_-75.655385_DE_IN_934.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/39.656506_-75.655385_DE_IN_934.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Industrial/39.727450_-75.549745_DE_IN_914.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Industrial/39.727450_-75.549745_DE_IN_914.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Hospital/40.120260_102.736711_HL_CO_133.tif.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/40.120260_102.736711_HL_CO_133.tif.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Hospital/39.716209_105.129280_HL_CO_141.tif.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/39.716209_105.129280_HL_CO_141.tif.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Hospital/40.412992_105.051478_HL_CO_143.tif.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/40.412992_105.051478_HL_CO_143.tif.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Hospital/39.951909_105.151782_HL_CO_139.tif.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/39.951909_105.151782_HL_CO_139.tif.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Hospital/34.750020_92.339394_HL_AR_28.tif.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/34.750020_92.339394_HL_AR_28.tif.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Hospital/34.279795_91.338231_HL_AR_17.tif.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/34.279795_91.338231_HL_AR_17.tif.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Hospital/35.784511_78.587902_NC_HL_904.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/35.784511_78.587902_NC_HL_904.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Hospital/36.650610_93.221869_MO_HL_829.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/36.650610_93.221869_MO_HL_829.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Hospital/45.794313_108.519053_MT_HL_868.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Hospital/45.794313_108.519053_MT_HL_868.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Single/36.032180_-115.107099_NV_SU_1094.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Single/36.032180_-115.107099_NV_SU_1094.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Single/41.255756_-96.002702_NE_SU_1049.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Single/41.255756_-96.002702_NE_SU_1049.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Single/25.748282_-80.208558_FL_SU_906.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Single/25.748282_-80.208558_FL_SU_906.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/High/238__34.049268_-118.249368_MU_CA_238.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/238__34.049268_-118.249368_MU_CA_238.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/High/24__40.753233_-74.004525_MU_NY_24.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/24__40.753233_-74.004525_MU_NY_24.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/High/39.955726_-75.168835_PA_HB_189.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/39.955726_-75.168835_PA_HB_189.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/High/35.224198_-80.848508__HB_50.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/35.224198_-80.848508__HB_50.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/High/40.764714_-73.976302_NY_HB_9.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/40.764714_-73.976302_NY_HB_9.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/High/35.228783_-80.841811__HB_51.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/35.228783_-80.841811__HB_51.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/High/40.759382_-73.973682_NY_HB_34.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/40.759382_-73.973682_NY_HB_34.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/High/40.724082_-74.005722_NY_HB_8.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/40.724082_-74.005722_NY_HB_8.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/High/40.762381_-73.971871_NY_HB_31.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/40.762381_-73.971871_NY_HB_31.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/High/36.095528_-80.243952_NC_HB_313.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/High/36.095528_-80.243952_NC_HB_313.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Commercial/37.786100_-122.420768_CO_CA_300.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/37.786100_-122.420768_CO_CA_300.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Commercial/34.144193_-118.755126_CO_CA_269.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/34.144193_-118.755126_CO_CA_269.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Commercial/34.049916_-118.243228_CO_CA_285.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/34.049916_-118.243228_CO_CA_285.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Commercial/34.129720_-118.747667_CO_CA_274.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/34.129720_-118.747667_CO_CA_274.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Commercial/33.774837_-118.417726_CO__256.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/33.774837_-118.417726_CO__256.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Commercial/39.025395_-77.146542_CO_MD_100.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/39.025395_-77.146542_CO_MD_100.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Commercial/34.081552_-118.413878_CO_CA_52.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/34.081552_-118.413878_CO_CA_52.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Commercial/37.777218_-122.393989_CO__396.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/37.777218_-122.393989_CO__396.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Commercial/33.830640_-84.367265_CO_GA_357.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/33.830640_-84.367265_CO_GA_357.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Commercial/33.838145_-84.381405_CO_GA_359.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Commercial/33.838145_-84.381405_CO_GA_359.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/School/13.446023_44.758462_SC_GU_129.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/13.446023_44.758462_SC_GU_129.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/School/29.988074_90.080518_SC_LA_49.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/29.988074_90.080518_SC_LA_49.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/School/39.028701_84.552118_SC_KY_43.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/39.028701_84.552118_SC_KY_43.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/School/29.976808_90.033521_SC_LA_50.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/29.976808_90.033521_SC_LA_50.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/School/29.989972_90.074578_SC_LA_47.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/29.989972_90.074578_SC_LA_47.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/School/44.913356_93.282341_SC_MN_71.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/44.913356_93.282341_SC_MN_71.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/School/32.835263_96.867355_SC_TX_87.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/32.835263_96.867355_SC_TX_87.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/School/44.896593_93.462305_SC_MN_65.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/44.896593_93.462305_SC_MN_65.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/School/37.773672_122.185074_SC_CA_21.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/37.773672_122.185074_SC_CA_21.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/School/35.231909_80.911501_SC_NC_2.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Schools/35.231909_80.911501_SC_NC_2.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Multi/267__33.794405_-84.450135_MU_GA_267.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/267__33.794405_-84.450135_MU_GA_267.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Multi/228__36.124941_-86.844921_MU__228.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/228__36.124941_-86.844921_MU__228.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Multi/265__37.773909_-122.441746_MU_CA_265.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/265__37.773909_-122.441746_MU_CA_265.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Multi/239__34.062738_-118.247128_MU_CA_239.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/239__34.062738_-118.247128_MU_CA_239.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Multi/223__33.764886_-118.406720_MU__223.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/223__33.764886_-118.406720_MU__223.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Multi/270__33.780660_-84.382082_MU_GA_270.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/270__33.780660_-84.382082_MU_GA_270.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Multi/197__40.767111_-73.991924_MU_NY_197.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/197__40.767111_-73.991924_MU_NY_197.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Multi/65__33.850689_-84.380928_MU_GA_65.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/65__33.850689_-84.380928_MU_GA_65.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Multi/77__33.780747_-84.382284_MU_GA_77.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/77__33.780747_-84.382284_MU_GA_77.tif
#
# Duplicate pair:
#   /content/drive/MyDrive/ML/Model/test/Multi/48__32.713245_-117.168684_MU_CA_48.tif
#   /content/drive/MyDrive/RA Satellite Imagery Work/Abduls RA Work Folder/SAT_Images/Phase 2/Multi/48__32.713245_-117.168684_MU_CA_48.tif

# %%
# %pip install imagehash
# Out:
# Collecting imagehash
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting PyWavelets (from imagehash)
#   Downloading pywavelets-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imagehash) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from imagehash) (10.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imagehash) (1.13.1)
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 4.4 MB/s eta 0:00:00
# Downloading pywavelets-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 66.1 MB/s eta 0:00:00
# Installing collected packages: PyWavelets, imagehash
# Successfully installed PyWavelets-1.7.0 imagehash-4.3.1

# %%
import numpy as np

# Define the confusion matrix
confusion_matrix = np.array([
    [8, 0, 0, 1, 1, 0, 0],
    [0,15, 0, 0, 0, 0, 0],
    [0, 0, 9, 0, 1, 0, 0],
    [0, 0, 0,11, 0, 0, 0],
    [1, 2, 0, 0, 7, 0, 1],
    [0, 0, 0, 0, 2, 8, 0],
    [0, 0, 0, 0, 0, 1, 9]
])

# Define the class labels
labels = ['Commercial', 'High', 'Hospital', 'Industrial', 'Multi', 'Schools', 'Single']

# Initialize a dictionary to store per-class accuracy
per_class_accuracy = {}

# Calculate per-class accuracy
for i in range(len(labels)):
    correct_predictions = confusion_matrix[i, i]
    total_samples = confusion_matrix[i, :].sum()
    accuracy = (correct_predictions / total_samples) * 100
    per_class_accuracy[labels[i]] = accuracy

# Display the per-class accuracy
for label in labels:
    print(f"Accuracy for class '{label}': {per_class_accuracy[label]:.2f}%")
# Out:
# Accuracy for class 'Commercial': 80.00%
# Accuracy for class 'High': 100.00%
# Accuracy for class 'Hospital': 90.00%
# Accuracy for class 'Industrial': 100.00%
# Accuracy for class 'Multi': 63.64%
# Accuracy for class 'Schools': 80.00%
# Accuracy for class 'Single': 90.00%
